# %%
# %%capture
import os
from pathlib import Path
import pandas as pd
from dj_notebook import activate
import numpy as np
from django_pandas.io import read_frame

env_file = os.environ["META_ENV"]
reports_folder = Path(os.environ["META_REPORTS_FOLDER"])
analysis_folder = Path(os.environ["META_ANALYSIS_FOLDER"])
pharmacy_folder = Path(os.environ["META_PHARMACY_FOLDER"])
plus = activate(dotenv_file=env_file)
pd.set_option('future.no_silent_downcasting', True)

# %%
import pdfkit
from datetime import date
from edc_pdutils.dataframes import get_subject_visit
from meta_analytics.dataframes import get_glucose_fbg_ogtt_df, get_glucose_fbg_df
from meta_visit_schedule.constants import MONTH15, MONTH18, MONTH21, MONTH27, MONTH30, MONTH33, MONTH39
from meta_analytics.dataframes import GlucoseEndpointsByDate
from scipy.stats import chi2
from great_tables import loc, style, md
from meta_analytics.dataframes import get_eos_df
from meta_analytics.utils import df_as_great_table, df_as_great_table2
from meta_prn.models import LossToFollowup
from edc_visit_schedule.models import SubjectScheduleHistory
from edc_appointment.analytics import get_appointment_df
from edc_appointment.constants import NEW_APPT, CANCELLED_APPT, ONTIME_APPT, MISSED_APPT, SCHEDULED_APPT, COMPLETE_APPT, INCOMPLETE_APPT, IN_PROGRESS_APPT, UNSCHEDULED_APPT
from edc_constants.constants import YES
from meta_consent.models import SubjectConsentV1Ext

# %%
html_data = []
cutoff_date = date(2025,3, 31)
end_of_trial_date= date(2026,3, 1)
document_title = f"<h2>Monitoring Report: {cutoff_date.strftime('%B %Y')}</h2><h5>Data Download: {cutoff_date.strftime('%d %B %Y')}</h5>"
study_title = 'META3 - Metformin treatment for diabetes prevention in Africa'
pdf_filename = f"monitoring_report_{cutoff_date.strftime('%Y%m%d')}.pdf"

# %%
df_visit = get_subject_visit("meta_subject.subjectvisit")
df_visit = df_visit[df_visit.appt_datetime.dt.date<=cutoff_date]
df_appointments = get_appointment_df()
df_appointments["site_id"] = df_appointments.site_id.astype(str)
cls = GlucoseEndpointsByDate()
cls.run()
df_endpoint = cls.endpoint_only_df.copy()
df_glucose = get_glucose_fbg_ogtt_df()
df_glucose_fbg = get_glucose_fbg_df()
df_glucose = pd.concat([df_glucose, df_glucose_fbg])

enrolled = df_visit.copy()
enrolled["site_id"] = enrolled["site_id"].astype(str)
enrolled_pivot = (
    enrolled
    .query("visit_code==1000.0").groupby(["site_id"])
    .size()
    .reset_index()
    .pivot_table(columns="site_id", values=0, observed=True)
)
enrolled_pivot.columns.name=""
enrolled_pivot["total"] = enrolled_pivot[["10", "20","30","40","60"]].sum(axis=1)

# %%
column_headers = {"label": "Label", "visit_code": "Visit code", "10": "Hindu Mandal", "20": "Amana", "30": "Temeke", "40": "Mwananyamala", "60": "Mnazi Moja", "total": "Total"}
column_headers_with_str = {"label": "Label", "10_str": "Hindu Mandal", "20_str": "Amana", "30_str": "Temeke", "40_str": "Mwananyamala", "60_str": "Mnazi Moja", "total_str": "Total"}

# %%
# Table 1a Visits completed to date
df_tbl1 = df_visit[(df_visit.visit_code_sequence==0) & (df_visit.appt_timing==ONTIME_APPT) & ~(df_visit.appt_status.isin([NEW_APPT, CANCELLED_APPT]))].groupby(by=["visit_code", "site_id"]).size().to_frame().reset_index()
df_tbl1.columns = ["visit_code", "site_id", "visits"]
df1 = df_tbl1.pivot(index="visit_code", columns="site_id", values="visits").reset_index()
df1.columns.name = None
df1.columns = ['visit_code', "10", "20", "30", "40", "60"]
df1['total'] = df1[['10', '20', '30', '40', '60']].sum(axis=1)
df1.fillna(0, inplace=True)
df_attended = df1.copy().reset_index(drop=True)
df_attended = df_attended.fillna(0.0)

# %%
gt = df_as_great_table(
    df_attended[["visit_code", "10", "20", "30", "40", "60", "total"]],
    title="Table 1: Visits completed to date"
)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k!="label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .tab_source_note(source_note=f"Includes visits reports submitted for participants eventually withdrawn on late exclusion criteria.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="sqejpdoplu" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #sqejpdoplu table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #sqejpdoplu thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #sqejpdoplu p { margin: 0; padding: 0; }
#  #sqejpdoplu .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #sqejpdoplu .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #sqejpdoplu .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #sqejpdoplu .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #sqejpdoplu .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #sqejpdoplu .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #sqejpdoplu .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #sqejpdoplu .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #sqejpdoplu .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #sqejpdoplu .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #sqejpdoplu .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #sqejpdoplu .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #sqejpdoplu .gt_spanner_row { border-bottom-style: hidden; }
#  #sqejpdoplu .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #sqejpdoplu .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #sqejpdoplu .gt_from_md> :first-child { margin-top: 0; }
#  #sqejpdoplu .gt_from_md> :last-child { margin-bottom: 0; }
#  #sqejpdoplu .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #sqejpdoplu .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #sqejpdoplu .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #sqejpdoplu .gt_row_group_first td { border-top-width: 2px; }
#  #sqejpdoplu .gt_row_group_first th { border-top-width: 2px; }
#  #sqejpdoplu .gt_striped { background-color: #F4F4F4; }
#  #sqejpdoplu .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #sqejpdoplu .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #sqejpdoplu .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #sqejpdoplu .gt_left { text-align: left; }
#  #sqejpdoplu .gt_center { text-align: center; }
#  #sqejpdoplu .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #sqejpdoplu .gt_font_normal { font-weight: normal; }
#  #sqejpdoplu .gt_font_bold { font-weight: bold; }
#  #sqejpdoplu .gt_font_italic { font-style: italic; }
#  #sqejpdoplu .gt_super { font-size: 65%; }
#  #sqejpdoplu .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #sqejpdoplu .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1: Visits completed to date</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td sty

# %%
# Table 1b Total scheduled appointments
df_appt_pivot = (
    df_appointments.query("appt_reason==@SCHEDULED_APPT")
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)

df_appt_pivot["total"] = df_appt_pivot.iloc[:,1:].sum(axis=1)
df_appt_pivot.columns.name = None
gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1b: Total appointments",
    subtitle="Total possible appointments not including unscheduled appointments"

)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k!="label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="mvtgykcbfw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #mvtgykcbfw table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #mvtgykcbfw thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #mvtgykcbfw p { margin: 0; padding: 0; }
#  #mvtgykcbfw .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #mvtgykcbfw .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #mvtgykcbfw .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #mvtgykcbfw .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #mvtgykcbfw .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mvtgykcbfw .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #mvtgykcbfw .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mvtgykcbfw .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #mvtgykcbfw .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #mvtgykcbfw .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #mvtgykcbfw .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #mvtgykcbfw .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #mvtgykcbfw .gt_spanner_row { border-bottom-style: hidden; }
#  #mvtgykcbfw .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #mvtgykcbfw .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #mvtgykcbfw .gt_from_md> :first-child { margin-top: 0; }
#  #mvtgykcbfw .gt_from_md> :last-child { margin-bottom: 0; }
#  #mvtgykcbfw .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #mvtgykcbfw .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #mvtgykcbfw .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #mvtgykcbfw .gt_row_group_first td { border-top-width: 2px; }
#  #mvtgykcbfw .gt_row_group_first th { border-top-width: 2px; }
#  #mvtgykcbfw .gt_striped { background-color: #F4F4F4; }
#  #mvtgykcbfw .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #mvtgykcbfw .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #mvtgykcbfw .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #mvtgykcbfw .gt_left { text-align: left; }
#  #mvtgykcbfw .gt_center { text-align: center; }
#  #mvtgykcbfw .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #mvtgykcbfw .gt_font_normal { font-weight: normal; }
#  #mvtgykcbfw .gt_font_bold { font-weight: bold; }
#  #mvtgykcbfw .gt_font_italic { font-style: italic; }
#  #mvtgykcbfw .gt_super { font-size: 65%; }
#  #mvtgykcbfw .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #mvtgykcbfw .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1b: Total appointments</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Total possible appointments not including unscheduled appointments</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>

# %%
# Table 1c Past scheduled appointments -- no information provided
df_appt_pivot = (
    df_appointments.query("appt_datetime<@cutoff_date and appt_reason==@SCHEDULED_APPT and appt_timing==@ONTIME_APPT and appt_status.isin([@NEW_APPT])")
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)
df_appt_pivot["total"] = df_appt_pivot.iloc[:,1:].sum(axis=1)
df_appt_pivot.columns.name = None
gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1c: Past appointments not attended/not reported",
    subtitle="Expected by now but no information provided by site",
)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k!="label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .tab_source_note(source_note=f"Scheduled appointment date is before {cutoff_date.strftime('%d %B %Y')}.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="pwiamnqlnt" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #pwiamnqlnt table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #pwiamnqlnt thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #pwiamnqlnt p { margin: 0; padding: 0; }
#  #pwiamnqlnt .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #pwiamnqlnt .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #pwiamnqlnt .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #pwiamnqlnt .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #pwiamnqlnt .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #pwiamnqlnt .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #pwiamnqlnt .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #pwiamnqlnt .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #pwiamnqlnt .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #pwiamnqlnt .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #pwiamnqlnt .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #pwiamnqlnt .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #pwiamnqlnt .gt_spanner_row { border-bottom-style: hidden; }
#  #pwiamnqlnt .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #pwiamnqlnt .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #pwiamnqlnt .gt_from_md> :first-child { margin-top: 0; }
#  #pwiamnqlnt .gt_from_md> :last-child { margin-bottom: 0; }
#  #pwiamnqlnt .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #pwiamnqlnt .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #pwiamnqlnt .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #pwiamnqlnt .gt_row_group_first td { border-top-width: 2px; }
#  #pwiamnqlnt .gt_row_group_first th { border-top-width: 2px; }
#  #pwiamnqlnt .gt_striped { background-color: #F4F4F4; }
#  #pwiamnqlnt .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #pwiamnqlnt .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #pwiamnqlnt .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #pwiamnqlnt .gt_left { text-align: left; }
#  #pwiamnqlnt .gt_center { text-align: center; }
#  #pwiamnqlnt .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #pwiamnqlnt .gt_font_normal { font-weight: normal; }
#  #pwiamnqlnt .gt_font_bold { font-weight: bold; }
#  #pwiamnqlnt .gt_font_italic { font-style: italic; }
#  #pwiamnqlnt .gt_super { font-size: 65%; }
#  #pwiamnqlnt .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #pwiamnqlnt .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1c: Past appointments not attended/not reported</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Expected by now but no information provided by site</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi M

# %%
# Table 1d Unscheduled appointments
df_appt = df_appointments.query("appt_reason==@UNSCHEDULED_APPT and appt_timing==@ONTIME_APPT and appt_status!=@NEW_APPT").copy().reset_index(drop=True)
df_appt['visit_code'] = df_appt['visit_code'].astype(int)
df_appt['visit_code'] = df_appt['visit_code'].astype(str)

subjects_with_unscheduled = df_appt.subject_identifier.nunique()

df_appt_pivot = (
    df_appt
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)
df_appt_pivot["total"] = df_appt_pivot.iloc[:,1:].sum(axis=1)
df_appt_pivot.columns.name = None
df_appt_pivot[["10", "20", "30", "40", "60", "total"]] = df_appt_pivot[["10", "20", "30", "40", "60", "total"]].astype('float64')


# add totals row
sum_row = df_appt_pivot.select_dtypes(include='float64').sum()
sum_row['visit_code'] = 'Total'
sum_row_df = pd.DataFrame(sum_row).T
df_appt_pivot = pd.concat([df_appt_pivot, sum_row_df], axis=0).reset_index(drop=True)

gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1d: Unscheduled appointments",
    subtitle="Appointments with sequence>0 grouped by visit code",
)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k!="label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .fmt_number(columns=["10", "20", "30", "40", "60", "total"], decimals=0)
    .tab_source_note(source_note=f"{subjects_with_unscheduled} participants had at least one unscheduled appointment.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="jldsiopmny" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #jldsiopmny table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #jldsiopmny thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #jldsiopmny p { margin: 0; padding: 0; }
#  #jldsiopmny .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #jldsiopmny .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #jldsiopmny .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #jldsiopmny .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #jldsiopmny .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jldsiopmny .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #jldsiopmny .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jldsiopmny .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #jldsiopmny .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #jldsiopmny .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #jldsiopmny .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #jldsiopmny .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #jldsiopmny .gt_spanner_row { border-bottom-style: hidden; }
#  #jldsiopmny .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #jldsiopmny .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #jldsiopmny .gt_from_md> :first-child { margin-top: 0; }
#  #jldsiopmny .gt_from_md> :last-child { margin-bottom: 0; }
#  #jldsiopmny .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #jldsiopmny .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #jldsiopmny .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #jldsiopmny .gt_row_group_first td { border-top-width: 2px; }
#  #jldsiopmny .gt_row_group_first th { border-top-width: 2px; }
#  #jldsiopmny .gt_striped { background-color: #F4F4F4; }
#  #jldsiopmny .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #jldsiopmny .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #jldsiopmny .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #jldsiopmny .gt_left { text-align: left; }
#  #jldsiopmny .gt_center { text-align: center; }
#  #jldsiopmny .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #jldsiopmny .gt_font_normal { font-weight: normal; }
#  #jldsiopmny .gt_font_bold { font-weight: bold; }
#  #jldsiopmny .gt_font_italic { font-style: italic; }
#  #jldsiopmny .gt_super { font-size: 65%; }
#  #jldsiopmny .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #jldsiopmny .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1d: Unscheduled appointments</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Appointments with sequence&gt;0 grouped by visit code</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th cl

# %%
# Table 1e Future scheduled appointments
df_appt_pivot = (
    df_appointments.query("@cutoff_date<=appt_datetime<@end_of_trial_date and appt_reason==@SCHEDULED_APPT and appt_timing==@ONTIME_APPT and appt_status.isin([@NEW_APPT])")
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)
df_appt_pivot["total"] = df_appt_pivot.iloc[:,1:].sum(axis=1)
df_appt_pivot.columns.name = None
gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1e: Future appointments",
)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k!="label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .fmt_number(columns=["10", "20", "30", "40", "60", "total"], decimals=0)
    .tab_source_note(source_note=f"Scheduled appointment date is on or after {cutoff_date.strftime('%d %B %Y')} and before {end_of_trial_date.strftime('%d %B %Y')}.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="dveybenrfv" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #dveybenrfv table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #dveybenrfv thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #dveybenrfv p { margin: 0; padding: 0; }
#  #dveybenrfv .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #dveybenrfv .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #dveybenrfv .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #dveybenrfv .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #dveybenrfv .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dveybenrfv .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #dveybenrfv .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dveybenrfv .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #dveybenrfv .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #dveybenrfv .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #dveybenrfv .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #dveybenrfv .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #dveybenrfv .gt_spanner_row { border-bottom-style: hidden; }
#  #dveybenrfv .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #dveybenrfv .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #dveybenrfv .gt_from_md> :first-child { margin-top: 0; }
#  #dveybenrfv .gt_from_md> :last-child { margin-bottom: 0; }
#  #dveybenrfv .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #dveybenrfv .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #dveybenrfv .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #dveybenrfv .gt_row_group_first td { border-top-width: 2px; }
#  #dveybenrfv .gt_row_group_first th { border-top-width: 2px; }
#  #dveybenrfv .gt_striped { background-color: #F4F4F4; }
#  #dveybenrfv .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #dveybenrfv .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #dveybenrfv .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #dveybenrfv .gt_left { text-align: left; }
#  #dveybenrfv .gt_center { text-align: center; }
#  #dveybenrfv .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #dveybenrfv .gt_font_normal { font-weight: normal; }
#  #dveybenrfv .gt_font_bold { font-weight: bold; }
#  #dveybenrfv .gt_font_italic { font-style: italic; }
#  #dveybenrfv .gt_super { font-size: 65%; }
#  #dveybenrfv .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #dveybenrfv .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1e: Future appointments</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td style="

# %%
# Table 2 Visits Missed to Date as % of Visits Attended + Visits Missed
subject_count = df_visit.query("visit_code_sequence==0 and appt_timing==@MISSED_APPT and ~appt_status.isin([@NEW_APPT, @CANCELLED_APPT])").subject_identifier.nunique()
df_tbl = (
    df_visit[(df_visit.visit_code_sequence==0) & (df_visit.appt_timing==MISSED_APPT) & ~(df_visit.appt_status.isin([NEW_APPT, CANCELLED_APPT]))]
    .groupby(by=["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
)
df_tbl.columns = ["visit_code", "site_id", "visits"]
df_tbl_pivot = df_tbl.pivot(index="visit_code", columns="site_id", values="visits").reset_index()
df_tbl_pivot.columns.name = None
df_tbl_pivot.columns = ['visit_code', "10", "20", "30", "40", "60"]
df_tbl_pivot['total'] = df_tbl_pivot[['10', '20', '30', '40', '60']].sum(axis=1)
df_missed = (
    df_tbl_pivot
    .fillna(0)
    .copy()
    .set_index(["visit_code"])
)

df_attended_display = df_attended.copy()
df_attended_display = (
    df_attended_display
    .set_index(["visit_code"])
)

attended_and_missed = df_attended_display + df_missed
attended_and_missed = (
    attended_and_missed
    .fillna(0)
    .reset_index()
    .set_index(["visit_code"])
)

attended_and_missed_perc = df_missed/attended_and_missed
attended_and_missed_perc = (
    attended_and_missed_perc
    .fillna(0)
    .reset_index()
    .set_index(["visit_code"])
)

df_result = df_missed.merge(attended_and_missed_perc, on=["visit_code"], suffixes=("", "_perc"))
for col in  ["10", "20", "30", "40", "60", "total"]:
    col_perc = f"{col}_perc"
    df_result[col] = df_result.apply(lambda x: f"{x[col]} ({x[col_perc]*100:.2f})", axis=1)
df_result = df_result.reset_index().sort_values(by=["visit_code"], ascending=True)
df_result = df_result.fillna(0.0)

# %%
df_table = df_result[["visit_code", "10", "20", "30", "40", "60", "total"]].copy()
gt = df_as_great_table(
    df_table,
    title="Table 2a: Visits Missed to Date",
    subtitle="as % of Visits Attended + Visits Missed"
)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k!="label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code", "label"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=list(range(0, len(df_table))),
        ),
    )
    .tab_source_note(source_note=f"{subject_count} participants had at least one missed visit.")

)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="klghkgkfzo" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #klghkgkfzo table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #klghkgkfzo thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #klghkgkfzo p { margin: 0; padding: 0; }
#  #klghkgkfzo .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #klghkgkfzo .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #klghkgkfzo .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #klghkgkfzo .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #klghkgkfzo .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #klghkgkfzo .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #klghkgkfzo .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #klghkgkfzo .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #klghkgkfzo .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #klghkgkfzo .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #klghkgkfzo .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #klghkgkfzo .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #klghkgkfzo .gt_spanner_row { border-bottom-style: hidden; }
#  #klghkgkfzo .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #klghkgkfzo .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #klghkgkfzo .gt_from_md> :first-child { margin-top: 0; }
#  #klghkgkfzo .gt_from_md> :last-child { margin-bottom: 0; }
#  #klghkgkfzo .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #klghkgkfzo .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #klghkgkfzo .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #klghkgkfzo .gt_row_group_first td { border-top-width: 2px; }
#  #klghkgkfzo .gt_row_group_first th { border-top-width: 2px; }
#  #klghkgkfzo .gt_striped { background-color: #F4F4F4; }
#  #klghkgkfzo .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #klghkgkfzo .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #klghkgkfzo .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #klghkgkfzo .gt_left { text-align: left; }
#  #klghkgkfzo .gt_center { text-align: center; }
#  #klghkgkfzo .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #klghkgkfzo .gt_font_normal { font-weight: normal; }
#  #klghkgkfzo .gt_font_bold { font-weight: bold; }
#  #klghkgkfzo .gt_font_italic { font-style: italic; }
#  #klghkgkfzo .gt_super { font-size: 65%; }
#  #klghkgkfzo .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #klghkgkfzo .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 2a: Visits Missed to Date</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">as % of Visits Attended + Visits Missed</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_headi

# %%
# Table 2b: Number of missed visits by participant
subject_count = df_visit.query("visit_code_sequence==0 and appt_timing==@MISSED_APPT and ~appt_status.isin([@NEW_APPT, @CANCELLED_APPT])").subject_identifier.nunique()
df_tbl = (
    df_visit[(df_visit.visit_code_sequence==0) & (df_visit.appt_timing==MISSED_APPT) & ~(df_visit.appt_status.isin([NEW_APPT, CANCELLED_APPT]))]
    .groupby(by=["subject_identifier", "site_id"])
    .size()
    .to_frame()
    .reset_index()
)
df_tbl.columns = ["subject_identifier", "site_id", "missed_count"]
df_tbl["category"] = pd.cut(df_tbl["missed_count"], bins=[0, 1, 3, 5, 7, 100], labels=["Missed at least 1", "2 to 3", "4 to 5", "6 to 7", "missed more than 7"])
df_tbl_pivot = df_tbl.pivot_table(index="category", columns="site_id", values="missed_count", observed=False, aggfunc="count").reset_index()

df_tbl_pivot['total'] = df_tbl_pivot.select_dtypes(include='int').sum(axis=1, skipna=True)

sum_row = df_tbl_pivot.select_dtypes(include='int64').sum()
sum_row['category'] = 'Total'


df_tbl_pivot = (
    pd.concat([df_tbl_pivot, sum_row.to_frame().T], axis=0)
    .rename(columns={10: "10", 20: "20", 30: "30", 40: "40", 60: "60"})
)

gt = df_as_great_table(
    df_tbl_pivot,
    title="Table 2b: Number of participants who missed one or more visits",
)
gt = (
    gt
    .cols_label({"category": "Category", **{k:v for k, v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["category"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=list(range(0, len(df_table))),
        ),
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="ewskasdtyo" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ewskasdtyo table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ewskasdtyo thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ewskasdtyo p { margin: 0; padding: 0; }
#  #ewskasdtyo .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ewskasdtyo .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ewskasdtyo .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #ewskasdtyo .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #ewskasdtyo .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ewskasdtyo .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ewskasdtyo .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ewskasdtyo .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ewskasdtyo .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ewskasdtyo .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ewskasdtyo .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ewskasdtyo .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ewskasdtyo .gt_spanner_row { border-bottom-style: hidden; }
#  #ewskasdtyo .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ewskasdtyo .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #ewskasdtyo .gt_from_md> :first-child { margin-top: 0; }
#  #ewskasdtyo .gt_from_md> :last-child { margin-bottom: 0; }
#  #ewskasdtyo .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #ewskasdtyo .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #ewskasdtyo .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ewskasdtyo .gt_row_group_first td { border-top-width: 2px; }
#  #ewskasdtyo .gt_row_group_first th { border-top-width: 2px; }
#  #ewskasdtyo .gt_striped { background-color: #F4F4F4; }
#  #ewskasdtyo .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ewskasdtyo .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ewskasdtyo .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ewskasdtyo .gt_left { text-align: left; }
#  #ewskasdtyo .gt_center { text-align: center; }
#  #ewskasdtyo .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ewskasdtyo .gt_font_normal { font-weight: normal; }
#  #ewskasdtyo .gt_font_bold { font-weight: bold; }
#  #ewskasdtyo .gt_font_italic { font-style: italic; }
#  #ewskasdtyo .gt_super { font-size: 65%; }
#  #ewskasdtyo .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ewskasdtyo .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 2b: Number of participants who missed one or more visits</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="category">Category</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_

# %%
# func for tables 3,4,5
def get_row_df(row_df:pd.DataFrame, label:str)->pd.DataFrame:
    row_df = row_df.groupby(by=["site_id"]).site_id.count().to_frame(name="n")
    row_df["label"] = label
    row_df = row_df.reset_index()
    row_df = row_df.pivot(index="label", values="n", columns="site_id").reset_index()
    row_df.columns.name = ""
    all_sites = [10, 20, 30, 40, 60]
    for site in all_sites:
        if site not in row_df.columns:
            row_df[site] = None
    row_df = row_df.reset_index(drop=True)
    return row_df


def get_table_df(df_source:pd.DataFrame, visit_code:float)->pd.DataFrame:
    df_month = df_source[df_source.visit_code==visit_code].copy()
    
    row_df = df_month.copy()
    table_df = get_row_df(row_df, "Total (n)")
    
    row_df = df_month.query("ogtt_value<7.8 and fbg_value<6.1").copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT <7.8; FBG <6.1")])
    
    row_df = df_month[(df_month.ogtt_value<7.8) & (df_month.fbg_value>=6.1) & (df_month.fbg_value<7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT <7.8; FBG >=6.1 <7.0")])
    
    row_df = df_month[(df_month.ogtt_value<7.8) & (df_month.fbg_value>=7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT <7.8; FBG >=7.0")])
    
    row_df = df_month[(df_month.ogtt_value>=7.8) & (df_month.ogtt_value<11.1) & (df_month.fbg_value<6.1)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT ≥7.8 to <11.1; FBG <6.1")])
    
    row_df = df_month[(df_month.ogtt_value>=7.8) & (df_month.ogtt_value<11.1) & (df_month.fbg_value>=6.1) & (df_month.fbg_value<7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT ≥7.8 to <11.1; FBG >=6.1 <7.0")])
    
    row_df = df_month[(df_month.ogtt_value>=7.8) & (df_month.ogtt_value<11.1) & (df_month.fbg_value>=7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT ≥7.8 to <11.1; FBG >=7.0")])
    
    row_df = df_month[(df_month.ogtt_value>=11.1) & (df_month.fbg_value<6.1)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT ≥11.1; FBG <6.1")])
    
    row_df = df_month[(df_month.ogtt_value>=11.1) & (df_month.fbg_value>=6.1) & (df_month.fbg_value<7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT ≥11.1; FBG >=6.1 <7.0")])
    
    row_df = df_month[(df_month.ogtt_value>=11.1) & (df_month.fbg_value>=7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "OGTT ≥11.1; FBG >=7.0")])

    row_df = df_month[(df_month.ogtt_value.isna())].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "Missing OGTT")])
    return table_df


def format_table_df(tbl_df, add_totals:bool|None=None):
    add_totals = True if add_totals is None else add_totals
    tbl_df = tbl_df.fillna(0.0)
    tbl_df["total"] = tbl_df.iloc[:,1:].sum(axis=1)
    tbl_df = tbl_df.reset_index(drop=True)

    if add_totals:
        df_last = tbl_df[1:].sum().to_frame()
        df_last.loc["label"] = np.nan
        df_last = df_last.reset_index()
        df_last.columns = ["label", "value"]
        df_last = df_last.pivot_table(columns="label",  values="value").reset_index(drop=True)
        df_last.columns.name = ""
        df_last["label"] = "Totals"

        tbl_df = pd.concat([tbl_df, df_last])
        tbl_df = tbl_df.reset_index(drop=True)

    tbl_df.columns = ["label", "10", "20", "30", "40", "60", "total"]

    for site in ["10", "20", "30", "40", "60", "total"]:
        tbl_df[f"{site}_perc"] = (tbl_df[site]/tbl_df.iloc[0][site]) * 100 if tbl_df.iloc[0][site]>0 else 0
        tbl_df[f"{site}_perc_str"] = tbl_df[f"{site}_perc"].map('{:.1f}'.format)


    for site in ["10", "20", "30", "40", "60", "total"]:
        tbl_df[f"{site}_str"] = tbl_df[[f"{site}", f"{site}_perc_str"]].apply(lambda x: ' ('.join(x.astype(str)), axis=1)
        tbl_df[f"{site}_str"] = tbl_df[f"{site}_str"] + ")"

    cols = ["label", *[f"{site}_str" for site in ["10", "20", "30", "40", "60", "total"]]]
    tbl_df1 = tbl_df[cols]
    tbl_df1.loc[tbl_df.label=="Total (n)"] = tbl_df.iloc[0][["label", "10", "20", "30", "40", "60", "total"]].to_list()
    return tbl_df1

# %%
# Table 3: OGTT and FBG at 12-month visit
df_table3 = get_table_df(df_glucose, 1120.0)
df_table3 = format_table_df(df_table3)
df_table3 = df_table3.fillna(0.0)
gt = df_as_great_table(df_table3, title="Table 3: OGTT and FBG at 12-month visit")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="ppsftuemog" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ppsftuemog table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ppsftuemog thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ppsftuemog p { margin: 0; padding: 0; }
#  #ppsftuemog .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ppsftuemog .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ppsftuemog .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #ppsftuemog .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #ppsftuemog .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ppsftuemog .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ppsftuemog .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ppsftuemog .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ppsftuemog .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ppsftuemog .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ppsftuemog .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ppsftuemog .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ppsftuemog .gt_spanner_row { border-bottom-style: hidden; }
#  #ppsftuemog .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ppsftuemog .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #ppsftuemog .gt_from_md> :first-child { margin-top: 0; }
#  #ppsftuemog .gt_from_md> :last-child { margin-bottom: 0; }
#  #ppsftuemog .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #ppsftuemog .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #ppsftuemog .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ppsftuemog .gt_row_group_first td { border-top-width: 2px; }
#  #ppsftuemog .gt_row_group_first th { border-top-width: 2px; }
#  #ppsftuemog .gt_striped { background-color: #F4F4F4; }
#  #ppsftuemog .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ppsftuemog .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ppsftuemog .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ppsftuemog .gt_left { text-align: left; }
#  #ppsftuemog .gt_center { text-align: center; }
#  #ppsftuemog .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ppsftuemog .gt_font_normal { font-weight: normal; }
#  #ppsftuemog .gt_font_bold { font-weight: bold; }
#  #ppsftuemog .gt_font_italic { font-style: italic; }
#  #ppsftuemog .gt_super { font-size: 65%; }
#  #ppsftuemog .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ppsftuemog .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 3: OGTT and FBG at 12-month visit</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_h

# %%
# Table 4: OGTT and FBG at 24-month visit
df_table4 = get_table_df(df_glucose, 1240.0)
df_table4 = format_table_df(df_table4)
df_table4 = df_table4.fillna(0.0)
gt = df_as_great_table(df_table4, title="Table 4: OGTT and FBG at 24-month visit")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="dbqzodmxzc" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #dbqzodmxzc table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #dbqzodmxzc thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #dbqzodmxzc p { margin: 0; padding: 0; }
#  #dbqzodmxzc .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #dbqzodmxzc .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #dbqzodmxzc .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #dbqzodmxzc .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #dbqzodmxzc .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dbqzodmxzc .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #dbqzodmxzc .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dbqzodmxzc .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #dbqzodmxzc .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #dbqzodmxzc .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #dbqzodmxzc .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #dbqzodmxzc .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #dbqzodmxzc .gt_spanner_row { border-bottom-style: hidden; }
#  #dbqzodmxzc .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #dbqzodmxzc .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #dbqzodmxzc .gt_from_md> :first-child { margin-top: 0; }
#  #dbqzodmxzc .gt_from_md> :last-child { margin-bottom: 0; }
#  #dbqzodmxzc .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #dbqzodmxzc .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #dbqzodmxzc .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #dbqzodmxzc .gt_row_group_first td { border-top-width: 2px; }
#  #dbqzodmxzc .gt_row_group_first th { border-top-width: 2px; }
#  #dbqzodmxzc .gt_striped { background-color: #F4F4F4; }
#  #dbqzodmxzc .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #dbqzodmxzc .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #dbqzodmxzc .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #dbqzodmxzc .gt_left { text-align: left; }
#  #dbqzodmxzc .gt_center { text-align: center; }
#  #dbqzodmxzc .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #dbqzodmxzc .gt_font_normal { font-weight: normal; }
#  #dbqzodmxzc .gt_font_bold { font-weight: bold; }
#  #dbqzodmxzc .gt_font_italic { font-style: italic; }
#  #dbqzodmxzc .gt_super { font-size: 65%; }
#  #dbqzodmxzc .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #dbqzodmxzc .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 4: OGTT and FBG at 24-month visit</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_h

# %%
# Table 5: OGTT and FBG at 36-month visit
df_table5 = get_table_df(df_glucose, 1360.0)
df_table5 = format_table_df(df_table5)
df_table5 = df_table5.fillna(0.0)
gt = df_as_great_table(df_table5, title="Table 5: OGTT and FBG at 36-month visit")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="dlyrxdjpnv" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #dlyrxdjpnv table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #dlyrxdjpnv thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #dlyrxdjpnv p { margin: 0; padding: 0; }
#  #dlyrxdjpnv .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #dlyrxdjpnv .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #dlyrxdjpnv .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #dlyrxdjpnv .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #dlyrxdjpnv .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dlyrxdjpnv .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #dlyrxdjpnv .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #dlyrxdjpnv .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #dlyrxdjpnv .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #dlyrxdjpnv .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #dlyrxdjpnv .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #dlyrxdjpnv .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #dlyrxdjpnv .gt_spanner_row { border-bottom-style: hidden; }
#  #dlyrxdjpnv .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #dlyrxdjpnv .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #dlyrxdjpnv .gt_from_md> :first-child { margin-top: 0; }
#  #dlyrxdjpnv .gt_from_md> :last-child { margin-bottom: 0; }
#  #dlyrxdjpnv .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #dlyrxdjpnv .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #dlyrxdjpnv .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #dlyrxdjpnv .gt_row_group_first td { border-top-width: 2px; }
#  #dlyrxdjpnv .gt_row_group_first th { border-top-width: 2px; }
#  #dlyrxdjpnv .gt_striped { background-color: #F4F4F4; }
#  #dlyrxdjpnv .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #dlyrxdjpnv .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #dlyrxdjpnv .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #dlyrxdjpnv .gt_left { text-align: left; }
#  #dlyrxdjpnv .gt_center { text-align: center; }
#  #dlyrxdjpnv .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #dlyrxdjpnv .gt_font_normal { font-weight: normal; }
#  #dlyrxdjpnv .gt_font_bold { font-weight: bold; }
#  #dlyrxdjpnv .gt_font_italic { font-style: italic; }
#  #dlyrxdjpnv .gt_super { font-size: 65%; }
#  #dlyrxdjpnv .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #dlyrxdjpnv .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 5: OGTT and FBG at 36-month visit</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_h

# %%
# Table 6: Any OGTT>11.1 ever
row_df = df_glucose[df_glucose.ogtt_value>=11.1].copy()
table_df = get_row_df(row_df, "Total (n)")
df_table6 = format_table_df(table_df)
df_table = df_table6[:1].fillna(0.0).copy().reset_index(drop=True)
gt = df_as_great_table(df_table, title="Table 6: Any OGTT>11.1 ever")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})

)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="mnwmzdlubr" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #mnwmzdlubr table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #mnwmzdlubr thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #mnwmzdlubr p { margin: 0; padding: 0; }
#  #mnwmzdlubr .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #mnwmzdlubr .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #mnwmzdlubr .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #mnwmzdlubr .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #mnwmzdlubr .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mnwmzdlubr .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #mnwmzdlubr .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mnwmzdlubr .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #mnwmzdlubr .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #mnwmzdlubr .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #mnwmzdlubr .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #mnwmzdlubr .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #mnwmzdlubr .gt_spanner_row { border-bottom-style: hidden; }
#  #mnwmzdlubr .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #mnwmzdlubr .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #mnwmzdlubr .gt_from_md> :first-child { margin-top: 0; }
#  #mnwmzdlubr .gt_from_md> :last-child { margin-bottom: 0; }
#  #mnwmzdlubr .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #mnwmzdlubr .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #mnwmzdlubr .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #mnwmzdlubr .gt_row_group_first td { border-top-width: 2px; }
#  #mnwmzdlubr .gt_row_group_first th { border-top-width: 2px; }
#  #mnwmzdlubr .gt_striped { background-color: #F4F4F4; }
#  #mnwmzdlubr .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #mnwmzdlubr .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #mnwmzdlubr .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #mnwmzdlubr .gt_left { text-align: left; }
#  #mnwmzdlubr .gt_center { text-align: center; }
#  #mnwmzdlubr .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #mnwmzdlubr .gt_font_normal { font-weight: normal; }
#  #mnwmzdlubr .gt_font_bold { font-weight: bold; }
#  #mnwmzdlubr .gt_font_italic { font-style: italic; }
#  #mnwmzdlubr .gt_super { font-size: 65%; }
#  #mnwmzdlubr .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #mnwmzdlubr .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 6: Any OGTT>11.1 ever</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_heading gt_co

# %%
# func for table 7
def get_table7_df(df_source:pd.DataFrame, visit_code:float)->pd.DataFrame:
    df_month = df_source[(df_source.visit_code>=visit_code) & (df_source.visit_code<=visit_code + 0.9)].copy()

    row_df = df_month.copy()
    table_df = get_row_df(row_df, "Total (n)")

    row_df = df_month[(df_month.fbg_value<6.1)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "FBG <6.1")])

    row_df = df_month[(df_month.fbg_value>=6.1) & (df_month.fbg_value<7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "FBG >=6.1 <7.0")])

    row_df = df_month[(df_month.fbg_value>=7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "FBG >=7.0")])
    return table_df

# %%
# Table 7: Interim FBG results
df_table7 = get_table7_df(df_glucose, 1150.0)
df_table7 = format_table_df(df_table7, add_totals=False)
df_table7["visit_code"] = MONTH15

df_table71 = get_table7_df(df_glucose, 1180.0)
df_table71 = format_table_df(df_table71, add_totals=False)
df_table71["visit_code"] = MONTH18

df_table72 = get_table7_df(df_glucose, 1210.0)
df_table72 = format_table_df(df_table72, add_totals=False)
df_table72["visit_code"] = MONTH21

df_table73 = get_table7_df(df_glucose, 1270.0)
df_table73 = format_table_df(df_table73, add_totals=False)
df_table73["visit_code"] = MONTH27

df_table74 = get_table7_df(df_glucose, 1300.0)
df_table74 = format_table_df(df_table74, add_totals=False)
df_table74["visit_code"] = MONTH30

df_table75 = get_table7_df(df_glucose, 1330.0)
df_table75 = format_table_df(df_table75, add_totals=False)
df_table75["visit_code"] = MONTH33

df_table76 = get_table7_df(df_glucose, 1390.0)
df_table76 = format_table_df(df_table76, add_totals=False)
df_table76["visit_code"] = MONTH39

df_table = pd.concat([df_table7, df_table71, df_table72, df_table73, df_table74, df_table75, df_table76])
df_table = df_table.reset_index(drop=True)
df_table = df_table.fillna(0.0)

# %%
column_headers_with_str = {"visit_code": "Visit Code", **column_headers_with_str}
gt = df_as_great_table2(df_table, title="Table 7: Interim FBG results")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_move_to_start(columns="visit_code")
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["visit_code", "label"])
    .cols_width(cases={"label": "15%"})
    .tab_style(
        style=[
            style.text(color="black", weight="bold"),
            style.fill(color="lightgray")
        ],
        locations=loc.row_groups()
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="tfbfzjrwqp" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #tfbfzjrwqp table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #tfbfzjrwqp thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #tfbfzjrwqp p { margin: 0; padding: 0; }
#  #tfbfzjrwqp .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #tfbfzjrwqp .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #tfbfzjrwqp .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #tfbfzjrwqp .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #tfbfzjrwqp .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #tfbfzjrwqp .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #tfbfzjrwqp .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #tfbfzjrwqp .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #tfbfzjrwqp .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #tfbfzjrwqp .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #tfbfzjrwqp .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #tfbfzjrwqp .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #tfbfzjrwqp .gt_spanner_row { border-bottom-style: hidden; }
#  #tfbfzjrwqp .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #tfbfzjrwqp .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #tfbfzjrwqp .gt_from_md> :first-child { margin-top: 0; }
#  #tfbfzjrwqp .gt_from_md> :last-child { margin-bottom: 0; }
#  #tfbfzjrwqp .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #tfbfzjrwqp .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #tfbfzjrwqp .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #tfbfzjrwqp .gt_row_group_first td { border-top-width: 2px; }
#  #tfbfzjrwqp .gt_row_group_first th { border-top-width: 2px; }
#  #tfbfzjrwqp .gt_striped { background-color: #F4F4F4; }
#  #tfbfzjrwqp .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #tfbfzjrwqp .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #tfbfzjrwqp .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #tfbfzjrwqp .gt_left { text-align: left; }
#  #tfbfzjrwqp .gt_center { text-align: center; }
#  #tfbfzjrwqp .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #tfbfzjrwqp .gt_font_normal { font-weight: normal; }
#  #tfbfzjrwqp .gt_font_bold { font-weight: bold; }
#  #tfbfzjrwqp .gt_font_italic { font-style: italic; }
#  #tfbfzjrwqp .gt_super { font-size: 65%; }
#  #tfbfzjrwqp .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #tfbfzjrwqp .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:15%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 7: Interim FBG results</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bot

# %%
# Table 8: Primary Endpoint met
df_endpoint_grp = df_endpoint.groupby(by=["site_id", "endpoint_label"]).size().to_frame().reset_index()
df_endpoint_grp.columns = ["site_id", "label", "endpoints"]
df_endpoint_pivot = df_endpoint_grp.pivot_table(index="label", columns="site_id", values="endpoints").reset_index()
df_endpoint_pivot.columns.name = ""
df_endpoint_pivot.columns = ['label', "10", "20", "30", "40", "60"]
df_endpoint_pivot.loc[len(df_endpoint_pivot)] = df_endpoint_pivot[['10', '20', '30', '40', '60']].sum().to_dict()
df_endpoint_pivot.at[len(df_endpoint_pivot)-1, 'label'] = 'Total'
df_endpoint_pivot['total'] = df_endpoint_pivot[['10', '20', '30', '40', '60']].sum(axis=1)
df_endpoint_pivot = df_endpoint_pivot.fillna(0.0)

# %%
gt = df_as_great_table(
    df_endpoint_pivot,
    title="Table 8: Primary Endpoint met"
)
gt = (
    gt
    .cols_label({k:v for k, v in column_headers.items() if k not in ["visit_code"]})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "25%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="krejuszdia" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #krejuszdia table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #krejuszdia thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #krejuszdia p { margin: 0; padding: 0; }
#  #krejuszdia .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #krejuszdia .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #krejuszdia .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #krejuszdia .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #krejuszdia .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #krejuszdia .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #krejuszdia .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #krejuszdia .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #krejuszdia .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #krejuszdia .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #krejuszdia .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #krejuszdia .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #krejuszdia .gt_spanner_row { border-bottom-style: hidden; }
#  #krejuszdia .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #krejuszdia .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #krejuszdia .gt_from_md> :first-child { margin-top: 0; }
#  #krejuszdia .gt_from_md> :last-child { margin-bottom: 0; }
#  #krejuszdia .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #krejuszdia .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #krejuszdia .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #krejuszdia .gt_row_group_first td { border-top-width: 2px; }
#  #krejuszdia .gt_row_group_first th { border-top-width: 2px; }
#  #krejuszdia .gt_striped { background-color: #F4F4F4; }
#  #krejuszdia .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #krejuszdia .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #krejuszdia .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #krejuszdia .gt_left { text-align: left; }
#  #krejuszdia .gt_center { text-align: center; }
#  #krejuszdia .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #krejuszdia .gt_font_normal { font-weight: normal; }
#  #krejuszdia .gt_font_bold { font-weight: bold; }
#  #krejuszdia .gt_font_italic { font-style: italic; }
#  #krejuszdia .gt_super { font-size: 65%; }
#  #krejuszdia .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #krejuszdia .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:25%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 8: Primary Endpoint met</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_borde

# %%
# Table 9: Incident Rate per 1000 person years

def get_df_main(df_visit:pd.DataFrame, lower_days:float|None=None, upper_days:float|None=None):
    if not lower_days:
        lower_days = -1
    cutoff_datetime = df_visit.query("@lower_days<followup_days<=@upper_days").visit_datetime.max()
    # exclude subjects for this reason
    offstudy_reasons = ['Patient fulfilled late exclusion criteria (due to abnormal blood values or raised blood pressure at enrolment']

    df_eos = get_eos_df()
    df_eos_excluded = (
        df_eos
        .query("followup_days>@lower_days and followup_days<=@upper_days and offstudy_reason.isin(@offstudy_reasons)")
        .copy()
        .reset_index()
    )
    df_visit_final = (
        df_visit.query("@lower_days<followup_days<=@upper_days and reason!='missed' and visit_code<2000.0")
        .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", suffixes=("", "_y"), indicator=True)
        .query("_merge=='left_only'")
        .drop(columns=["_merge"])
    )
    df_main = (
        df_visit_final
        .groupby(by=["subject_identifier"])[["baseline_datetime", "visit_datetime", "followup_days"]]
        .max()
        .reset_index()
    )

    df_main = (
        df_main
        .merge(
            df_endpoint.query("days_to_endpoint>@lower_days")[["subject_identifier", "endpoint_label", "endpoint_type", "days_to_endpoint"]],
            how="left",
            on=["subject_identifier"])
        .reset_index(drop=True)
    )
    if lower_days>=365.25:
        df_main["followup_days"] = df_main["followup_days"] - lower_days
    df_main["followup_years"] = df_main["followup_days"]/365.25
    return df_main, len(df_main), len(df_main.query("@lower_days<days_to_endpoint<=@upper_days and endpoint_label.notna()"))

def get_rate_and_ci(events, person_years_total):
    lower_ci = (chi2.ppf(0.025, 2 * events) / (2 * person_years_total)) * 1000
    upper_ci = (chi2.ppf(0.975, 2 * (events + 1)) / (2 * person_years_total)) * 1000
    return events/person_years_total*1000, lower_ci, upper_ci

def get_incidence_data(term:str, lower_days:float, upper_days:float):
    data = {}
    df_main, subjects, events = get_df_main(df_visit, lower_days=lower_days, upper_days=upper_days)
    person_years_total = df_main.followup_years.sum()
    data.update({term:[person_years_total, subjects, events, *get_rate_and_ci(events, person_years_total)]})
    return data

# %%
incidence_data = {}
incidence_data.update(get_incidence_data("total", lower_days=-1, upper_days=10000))
incidence_data.update(get_incidence_data("0-1 years", lower_days=-1, upper_days=365.25))
incidence_data.update(get_incidence_data("1-2 years", lower_days=365.25, upper_days=2 * 365.25))
incidence_data.update(get_incidence_data("2-3 years", lower_days=2 * 365.25, upper_days=3 * 365.25))
incidence_data.update(get_incidence_data("3+ years", lower_days=3 * 365.25, upper_days=10 * 365.25))
data = dict(label=[], person_years=[], subjects=[], failures=[], rate=[], lower_ci=[], upper_ci=[])
for k in incidence_data:
    data["label"].append(k)

for v in incidence_data.values():
    data["person_years"].append(v[0])
    data["subjects"].append(v[1])
    data["failures"].append(v[2])
    data["rate"].append(v[3])
    data["lower_ci"].append(v[4])
    data["upper_ci"].append(v[5])

df_table9 = pd.DataFrame(data={k:v for k,v in data.items() if k!="subjects"})

# %%
gt = df_as_great_table(
    df_table9,
    title="Table 9: Incident Rate per 1000 person years",
    subtitle=md("using randomisation to diabetes/last seen"),
)
gt = gt.fmt_number(columns=["person_years", "failures", "rate", "lower_ci", "upper_ci"], decimals=2)
gt = (gt
    .cols_label({"label": "Label", "person_years": "Person years", "failures": "Failures", "rate": "Rate", "lower_ci": "Lower", "upper_ci": "Upper"})
    .cols_align(align="left", columns=["label"])
    .cols_align(align="center", columns=["person_years", "failures", "rate", "lower_ci", "upper_ci"])
    .tab_spanner(
        label="95%CI",
        columns=["lower_ci", "upper_ci"],
    )
    .tab_source_note(source_note="Excluding patients withdrawn for `late exclusion` criteria")
)
gt.show()
html_data.append(gt.as_raw_html())
# Out:
# <div id="smlihoeyjs" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #smlihoeyjs table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #smlihoeyjs thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #smlihoeyjs p { margin: 0; padding: 0; }
#  #smlihoeyjs .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #smlihoeyjs .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #smlihoeyjs .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #smlihoeyjs .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #smlihoeyjs .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #smlihoeyjs .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #smlihoeyjs .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #smlihoeyjs .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #smlihoeyjs .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #smlihoeyjs .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #smlihoeyjs .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #smlihoeyjs .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #smlihoeyjs .gt_spanner_row { border-bottom-style: hidden; }
#  #smlihoeyjs .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #smlihoeyjs .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #smlihoeyjs .gt_from_md> :first-child { margin-top: 0; }
#  #smlihoeyjs .gt_from_md> :last-child { margin-bottom: 0; }
#  #smlihoeyjs .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #smlihoeyjs .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #smlihoeyjs .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #smlihoeyjs .gt_row_group_first td { border-top-width: 2px; }
#  #smlihoeyjs .gt_row_group_first th { border-top-width: 2px; }
#  #smlihoeyjs .gt_striped { background-color: #F4F4F4; }
#  #smlihoeyjs .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #smlihoeyjs .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #smlihoeyjs .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #smlihoeyjs .gt_left { text-align: left; }
#  #smlihoeyjs .gt_center { text-align: center; }
#  #smlihoeyjs .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #smlihoeyjs .gt_font_normal { font-weight: normal; }
#  #smlihoeyjs .gt_font_bold { font-weight: bold; }
#  #smlihoeyjs .gt_font_italic { font-style: italic; }
#  #smlihoeyjs .gt_super { font-size: 65%; }
#  #smlihoeyjs .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #smlihoeyjs .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 9: Incident Rate per 1000 person years</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">using randomisation to diabetes/last seen</td>
#   </tr>
# <tr class="gt_col_headings gt_spanner_row">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="2" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="person_years">Person years</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="failures">Failures</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="rate">Rate</th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="95%CI">
#     <span class="gt_column_spanner">95%CI</span>
#   </th>
# </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_h

# %%
# Table 10: Proportion meeting primary endpoint
df_table10 = pd.DataFrame(data=data)
df_table10["proportion"] = df_table10["failures"]/df_table10["subjects"]*100
gt = df_as_great_table(
    df_table10[["label", "subjects", 'failures', "proportion"]],
    title="Table 10: Proportion meeting primary endpoint",
)
gt = (
    gt
    .fmt_number(columns=["failures", "proportion"], decimals=2)
    .cols_label({"label": "Label", "subjects": "Participants", "failures": "Failures", "proportion": "%"})
    .cols_align(align="left", columns=["label"])
    .cols_align(align="center", columns=["subjects", "failures", "proportion"])
    .tab_source_note(source_note="Excluding patients withdrawn for `late exclusion` criteria")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="zwhojdyhlj" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #zwhojdyhlj table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #zwhojdyhlj thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #zwhojdyhlj p { margin: 0; padding: 0; }
#  #zwhojdyhlj .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #zwhojdyhlj .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #zwhojdyhlj .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #zwhojdyhlj .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #zwhojdyhlj .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #zwhojdyhlj .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #zwhojdyhlj .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #zwhojdyhlj .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #zwhojdyhlj .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #zwhojdyhlj .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #zwhojdyhlj .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #zwhojdyhlj .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #zwhojdyhlj .gt_spanner_row { border-bottom-style: hidden; }
#  #zwhojdyhlj .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #zwhojdyhlj .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #zwhojdyhlj .gt_from_md> :first-child { margin-top: 0; }
#  #zwhojdyhlj .gt_from_md> :last-child { margin-bottom: 0; }
#  #zwhojdyhlj .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #zwhojdyhlj .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #zwhojdyhlj .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #zwhojdyhlj .gt_row_group_first td { border-top-width: 2px; }
#  #zwhojdyhlj .gt_row_group_first th { border-top-width: 2px; }
#  #zwhojdyhlj .gt_striped { background-color: #F4F4F4; }
#  #zwhojdyhlj .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #zwhojdyhlj .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #zwhojdyhlj .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #zwhojdyhlj .gt_left { text-align: left; }
#  #zwhojdyhlj .gt_center { text-align: center; }
#  #zwhojdyhlj .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #zwhojdyhlj .gt_font_normal { font-weight: normal; }
#  #zwhojdyhlj .gt_font_bold { font-weight: bold; }
#  #zwhojdyhlj .gt_font_italic { font-style: italic; }
#  #zwhojdyhlj .gt_super { font-size: 65%; }
#  #zwhojdyhlj .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #zwhojdyhlj .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 10: Proportion meeting primary endpoint</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="subjects">Participants</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="failures">Failures</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="proportion">%</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td style="background-color: snow; color: black; background-color: lightgray; color: black;" class="gt_row gt_left">total</td>
#     <td style="background-color: snow; color: black;" class="gt_row gt_center">1631</td>
#     <td style="background-color: snow; color: black;" class="gt_row gt_center">70.00</td>
#     <td style="background-color: snow; color: black;"

# %%
# Table 11a: End of Study Table (for those who have completed an end of study form)
df_eos = get_eos_df()
offstudy_reasons = {
    "Delivered / Completed followup from pregnancy": "Pregnancy",
    "Patient completed 36 months of follow-up": "Completed 36m",
    "Patient developed diabetes": "Developed diabetes",
    "Other reason (specify below)": "Other",
    "Patient fulfilled late exclusion criteria (due to abnormal blood values or raised blood pressure at enrolment": "Late exclusion",
    "Patient has been transferred to another health centre": "Transferred out",
    "Patient is withdrawn on CLINICAL grounds ...": "Withdrawal: Clinical grounds",
    "Patient lost to follow-up": "LTFU",
    "Patient reported/known to have died": "Died",
    "Patient withdrew consent to participate further": "Withdrawal: Consent",
}
df_eos["offstudy_reason"] = df_eos["offstudy_reason"].map(offstudy_reasons)
df_eos["offstudy_reason"] = pd.Categorical(df_eos["offstudy_reason"], categories=sorted(list(offstudy_reasons.values())), ordered=True)
df_eos["site_id"] = df_eos["site_id"].astype(str)
df_eos_pivot = (
    df_eos
    .groupby(by=["offstudy_reason", "site_id"],observed=True)
    .size()
    .reset_index()
    .pivot_table(index="offstudy_reason", columns="site_id", values=0, observed=True)
    .fillna(0)
    .astype(int)
    .reset_index()
)
df_eos_pivot["total"] = df_eos_pivot[["10", "20","30","40","60"]].sum(axis=1)
df_eos_pivot.columns.name=""
sum_row = df_eos_pivot.select_dtypes(include='int64').sum()
sum_row['offstudy_reason'] = 'Total'
sum_row_df = pd.DataFrame(sum_row).T
enrolled_pivot["offstudy_reason"] = "Enrolled"
enrolled_pivot = enrolled_pivot[[*df_eos_pivot.columns]]
df_eos_pivot = pd.concat([enrolled_pivot, df_eos_pivot, sum_row_df], ignore_index=True)

gt = df_as_great_table(
    df_eos_pivot,
    title="Table 11a: End of study report",
    subtitle=md("for those who have completed an End of study report"),
)
gt = (
    gt
    .cols_label({"offstudy_reason": "Reason", **{k:v for k,v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="left", columns=["offstudy_reason"])
    .cols_align(align="center", columns=["10", "20","30","40","60", "total"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=[len(df_eos_pivot)-1]),
        )
    .tab_style(
        style=[style.fill(color="lightblue"), style.text(color="black")],
        locations=loc.body(
            columns=["10", "20", "30", "40", "60"],
            rows=[len(df_eos_pivot)-1],
        ),
    )
    .tab_style(
        style=[style.fill(color="lightgreen"), style.text(color="black")],
        locations=loc.body(
            columns=["total"],
            rows=[len(df_eos_pivot)-1],
        ),
    )
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=["offstudy_reason"],
            rows=[0],
        ),
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="wttcrywqbw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #wttcrywqbw table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #wttcrywqbw thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #wttcrywqbw p { margin: 0; padding: 0; }
#  #wttcrywqbw .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #wttcrywqbw .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #wttcrywqbw .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #wttcrywqbw .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #wttcrywqbw .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wttcrywqbw .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #wttcrywqbw .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wttcrywqbw .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #wttcrywqbw .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #wttcrywqbw .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #wttcrywqbw .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #wttcrywqbw .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #wttcrywqbw .gt_spanner_row { border-bottom-style: hidden; }
#  #wttcrywqbw .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #wttcrywqbw .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #wttcrywqbw .gt_from_md> :first-child { margin-top: 0; }
#  #wttcrywqbw .gt_from_md> :last-child { margin-bottom: 0; }
#  #wttcrywqbw .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #wttcrywqbw .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #wttcrywqbw .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #wttcrywqbw .gt_row_group_first td { border-top-width: 2px; }
#  #wttcrywqbw .gt_row_group_first th { border-top-width: 2px; }
#  #wttcrywqbw .gt_striped { background-color: #F4F4F4; }
#  #wttcrywqbw .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #wttcrywqbw .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wttcrywqbw .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #wttcrywqbw .gt_left { text-align: left; }
#  #wttcrywqbw .gt_center { text-align: center; }
#  #wttcrywqbw .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #wttcrywqbw .gt_font_normal { font-weight: normal; }
#  #wttcrywqbw .gt_font_bold { font-weight: bold; }
#  #wttcrywqbw .gt_font_italic { font-style: italic; }
#  #wttcrywqbw .gt_super { font-size: 65%; }
#  #wttcrywqbw .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #wttcrywqbw .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 11a: End of study report</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">for those who have completed an End of study report</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="offstudy_reason">Reason</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="

# %%
# Table 11b: Study status
def get_schedule_df(df_subjecthistory:pd.DataFrame, onschedule_model:str, offschedule_model:str, mode:str)->pd.DataFrame:
    columns = {k:f"{k}_{mode}" for k in ["10", "20", "30", "40", "60"]}
    df_schedule = (
        df_subjecthistory
        .query(f"onschedule_model==@onschedule_model and offschedule_model==@offschedule_model and offschedule_datetime.{'isna' if mode=='on' else 'notna'}()")
        .groupby(by=["onschedule_model", "site_id"])
        .size()
        .reset_index()
        .pivot_table(index="onschedule_model", columns="site_id", values=0, observed=True)
        .reset_index()
        .rename(columns={"onschedule_model":"schedule", **columns})
        .fillna(0)
        .copy()
    )
    df_schedule.columns.name = ""
    return df_schedule

df_subjecthistory = read_frame(SubjectScheduleHistory.objects.all(), verbose=False).rename(columns={"site": "site_id"})
df_subjecthistory["site_id"] = df_subjecthistory["site_id"].astype(str)

df_on = pd.concat([
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedule', 'meta_prn.offschedule', "on"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onscheduledmreferral', 'meta_prn.offscheduledmreferral', "on"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedulepregnancy', 'meta_prn.offschedulepregnancy', "on"),
])

df_on = (
    df_on
    .fillna(0)
    .reset_index(drop=True)
)

df_off = pd.concat([
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedule', 'meta_prn.offschedule', "off"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onscheduledmreferral', 'meta_prn.offscheduledmreferral', "off"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedulepregnancy', 'meta_prn.offschedulepregnancy', "off"),
])
df_off = (
    df_off
    .fillna(0)
    .reset_index(drop=True)
)

df_status = pd.merge(df_on, df_off, on=["schedule"], how="outer")
columns = []
for ele in [[f"{x}_on", f"{x}_off"] for x in ["10", "20", "30", "40", "60"]]:
    columns.extend(ele)
df_status = df_status[["schedule", *columns]]
df_status["total_on"] = df_status[[col for col in columns if "on" in col]].sum(axis=1)
df_status["total_off"] = df_status[[col for col in columns if "off" in col]].sum(axis=1)
df_status["total"] = df_status[columns].sum(axis=1)
df_status["schedule"] = df_status.schedule.map({"meta_prn.onschedule": "Main trial", "meta_prn.onscheduledmreferral": "Diabetes", "meta_prn.onschedulepregnancy": "Pregnancy"})

gt = df_as_great_table(
    df_status,
    title="Table 11b: Study status",
    subtitle=md("Calculated from Offschedule form; not End of study report"),
)
# gt = gt.fmt_number(columns=["person_years", "failures", "rate", "lower_ci", "upper_ci"], decimals=0)
gt = (gt
    .tab_source_note(
        source_note=(
            "Note: Offschedule form is always submitted before the End of study report. "
            "When the Offschedule form is submitted, future appointments for the schedule are removed and "
            "the site staff are actioned to submit the End of study report."
        )
    )
    .cols_label({
        "10_on": "On", "10_off": "Off",
        "20_on": "On", "20_off": "Off",
        "30_on": "On", "30_off": "Off",
        "40_on": "On", "40_off": "Off",
        "60_on": "On", "60_off": "Off",
        "total_on": "On", "total_off": "Off",
        "schedule": "Schedule", "total": "Total"})
    .cols_align(align="center")
    .cols_align(align="left", columns=["label"])
    .tab_spanner(
        label="Hindu mandal",
        columns=["10_on", "10_off"],
    )
    .tab_spanner(
        label="Amana",
        columns=["20_on", "20_off"],
    )
    .tab_spanner(
        label="Temeke",
        columns=["30_on", "30_off"],
    )
    .tab_spanner(
        label="Mwananyamala",
        columns=["40_on", "40_off"],
    )
    .tab_spanner(
        label="Mnazi Moja",
        columns=["60_on", "60_off"],
    )
    .tab_spanner(
        label="Total",
        columns=["total_on", "total_off"],
    )
    .tab_style(
        style=[style.fill(color="lightblue"), style.text(color="black")],
        locations=loc.body(
            columns=["10_off", "20_off", "30_off", "40_off", "60_off"],
            rows=list(range(0, 1)),
        ),
    )
    .tab_style(
        style=[style.fill(color="lightgreen"), style.text(color="black")],
        locations=loc.body(
            columns=["total_off"],
            rows=list(range(0, 1)),
        ),
    )
    .fmt_number(columns=[*[c for c in df_status.columns if c not in ["schedule"]]], decimals=0)
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="kzmgyjrnpm" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #kzmgyjrnpm table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #kzmgyjrnpm thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #kzmgyjrnpm p { margin: 0; padding: 0; }
#  #kzmgyjrnpm .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #kzmgyjrnpm .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #kzmgyjrnpm .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #kzmgyjrnpm .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #kzmgyjrnpm .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #kzmgyjrnpm .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #kzmgyjrnpm .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #kzmgyjrnpm .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #kzmgyjrnpm .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #kzmgyjrnpm .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #kzmgyjrnpm .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #kzmgyjrnpm .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #kzmgyjrnpm .gt_spanner_row { border-bottom-style: hidden; }
#  #kzmgyjrnpm .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #kzmgyjrnpm .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #kzmgyjrnpm .gt_from_md> :first-child { margin-top: 0; }
#  #kzmgyjrnpm .gt_from_md> :last-child { margin-bottom: 0; }
#  #kzmgyjrnpm .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #kzmgyjrnpm .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #kzmgyjrnpm .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #kzmgyjrnpm .gt_row_group_first td { border-top-width: 2px; }
#  #kzmgyjrnpm .gt_row_group_first th { border-top-width: 2px; }
#  #kzmgyjrnpm .gt_striped { background-color: #F4F4F4; }
#  #kzmgyjrnpm .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #kzmgyjrnpm .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #kzmgyjrnpm .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #kzmgyjrnpm .gt_left { text-align: left; }
#  #kzmgyjrnpm .gt_center { text-align: center; }
#  #kzmgyjrnpm .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #kzmgyjrnpm .gt_font_normal { font-weight: normal; }
#  #kzmgyjrnpm .gt_font_bold { font-weight: bold; }
#  #kzmgyjrnpm .gt_font_italic { font-style: italic; }
#  #kzmgyjrnpm .gt_super { font-size: 65%; }
#  #kzmgyjrnpm .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #kzmgyjrnpm .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="14" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 11b: Study status</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="14" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Calculated from Offschedule form; not End of study report</td>
#   </tr>
# <tr class="gt_col_headings gt_spanner_row">
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="schedule">Schedule</th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="Hindu-mandal">
#     <span class="gt_column_spanner">Hindu mandal</span>
#   </th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="Amana">
#     <span class="gt_column_spanner">Amana</span>
#   </th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="Temeke">
#     <span class="gt_column_spanner">Temeke</span>
#   </th>
#   <th class="gt_center gt_columns_top_border gt_column_span

# %%
# Table 12: Loss to Follow Up
df_ltfu = read_frame(LossToFollowup.objects.all(), verbose=False).rename(columns={"site": "site_id"})
df_ltfu_pivot = (
    df_ltfu
    .groupby(by=["loss_category", "site_id"],observed=True,dropna=False)
    .size()
    .reset_index()
    .pivot_table(index="loss_category", columns="site_id", values=0, observed=True,dropna=False)
    .fillna(0)
    .astype(int)
    .reset_index()
)
df_ltfu_pivot["total"] = df_eos_pivot[["10", "20","30","40","60"]].sum(axis=1)
df_ltfu_pivot.columns.name=""
sum_row = df_ltfu_pivot.select_dtypes(include='int64').sum()
sum_row['loss_category'] = 'Total'
sum_row_df = pd.DataFrame(sum_row).T
df_ltfu_pivot = pd.concat([df_ltfu_pivot, sum_row_df], ignore_index=True)
df_ltfu_pivot
# Out:
#   loss_category 60   total
# 0         OTHER  1  1691.0
# 1         Total  1     NaN

# %%
# Table 11c: End of study report not submitted

df1 = (
    df_status
    .query("schedule=='Main trial'")[[col for col in columns if "off" in col]]
    .rename(columns=dict(zip([col for col in columns if "off" in col], ["10", "20","30","40","60"])))
    .reset_index(drop=True)
)
df2 = (
    df_eos_pivot
    .query("offstudy_reason=='Total'")[["10", "20","30","40","60"]]
    .reset_index(drop=True)
)

df_eos_not_reported = df1-df2
df_eos_not_reported["schedule"] = 'Main trial'
df_eos_not_reported["total"] = df_eos_not_reported[["10", "20","30","40","60"]].sum(axis=1)
df_eos_not_reported = df_eos_not_reported[["schedule", "10", "20","30","40","60", "total"]]

gt = df_as_great_table(
    df_eos_not_reported,
    title="Table 11c: End of study report not submitted",
    subtitle=md("End of study report expected based on Offschedule form"),
)
gt = (
    gt
    .cols_label({"schedule": "Schedule", **{k:v for k,v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="left", columns=["schedule"])
    .cols_align(align="center", columns=["10", "20","30","40","60", "total"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=[len(df_eos_pivot)-1]),
        )
    .tab_style(
        style=[style.fill(color="lightblue"), style.text(color="black")],
        locations=loc.body(
            columns=["10", "20", "30", "40", "60"],
            rows=[len(df_eos_pivot)-1],
        ),
    )
    .tab_style(
        style=[style.fill(color="lightgreen"), style.text(color="black")],
        locations=loc.body(
            columns=["total"],
            rows=[len(df_eos_pivot)-1],
        ),
    )
)
html_data.append(gt.as_raw_html())
gt.show()

# %%
# Table 13: Baseline Sample

# %%
# Table 15: Consented to extended followup
df_consented = (
    read_frame(SubjectConsentV1Ext.objects.all(), verbose=False)
    .query("agrees_to_extension==@YES")
    .rename(columns={"site": "site_id"})
)
df_consented["site_id"] = df_consented.site_id.astype(str)
df_consented["month"] = df_consented.report_datetime.dt.strftime("%m")
df_consented["year"] = df_consented.report_datetime.dt.strftime("%Y")
df_consented_grp = (
    df_consented.groupby(by=["site_id", "year", "month"]).
    size()
    .reset_index()
    .sort_values(by=["site_id", "year", "month"], ascending=True)
    .reset_index(drop=True)
)
df_consented_pivot = (
    df_consented_grp
    .pivot_table(index=["year", "month"], columns="site_id", values=0, aggfunc="sum")
    .reset_index()
    .fillna(0)
)
if "60" not in df_consented_pivot.columns:
    df_consented_pivot["60"] = 0.0 * len(df_consented_pivot)
df_consented_pivot.columns.name=""
df_consented_pivot["year"] = df_consented_pivot["year"].astype(str)
df_consented_pivot["month"] = df_consented_pivot["month"].astype(str)

sum_row = df_consented_pivot[["10", "20","30","40","60"]].sum()
sum_row['year'] = "Total"
sum_row['month'] = ""
df_consented_pivot = pd.concat([df_consented_pivot, sum_row.to_frame().T], ignore_index=True)
df_consented_pivot["total"] = df_consented_pivot[["10", "20","30","40","60"]].sum(axis=1).astype(int)
df_consented_pivot[["10", "20","30","40","60"]] = df_consented_pivot[["10", "20","30","40","60"]].astype(int)
gt = df_as_great_table2(
    df_consented_pivot,
    title="Table 15: Consented to extended followup",
    rowname_col="month",
    groupname_col="year",
)
gt = (
    gt
    .cols_label({"year": "Year", "month": "Month", **{k:v for k, v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="center")
    .fmt_number(columns=["10", "20", "30", "40", "60", "total"], decimals=0)
    .tab_stubhead(label="Consented")
    .tab_style(
        style=[
            style.text(color="black", weight="bold"),
            style.fill(color="lightgray")
        ],
        locations=loc.row_groups()
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="mddipuhlew" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #mddipuhlew table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #mddipuhlew thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #mddipuhlew p { margin: 0; padding: 0; }
#  #mddipuhlew .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #mddipuhlew .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #mddipuhlew .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #mddipuhlew .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #mddipuhlew .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mddipuhlew .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #mddipuhlew .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #mddipuhlew .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #mddipuhlew .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #mddipuhlew .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #mddipuhlew .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #mddipuhlew .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #mddipuhlew .gt_spanner_row { border-bottom-style: hidden; }
#  #mddipuhlew .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #mddipuhlew .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #mddipuhlew .gt_from_md> :first-child { margin-top: 0; }
#  #mddipuhlew .gt_from_md> :last-child { margin-bottom: 0; }
#  #mddipuhlew .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #mddipuhlew .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #mddipuhlew .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #mddipuhlew .gt_row_group_first td { border-top-width: 2px; }
#  #mddipuhlew .gt_row_group_first th { border-top-width: 2px; }
#  #mddipuhlew .gt_striped { background-color: #F4F4F4; }
#  #mddipuhlew .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #mddipuhlew .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #mddipuhlew .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #mddipuhlew .gt_left { text-align: left; }
#  #mddipuhlew .gt_center { text-align: center; }
#  #mddipuhlew .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #mddipuhlew .gt_font_normal { font-weight: normal; }
#  #mddipuhlew .gt_font_bold { font-weight: bold; }
#  #mddipuhlew .gt_font_italic { font-style: italic; }
#  #mddipuhlew .gt_super { font-size: 65%; }
#  #mddipuhlew .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #mddipuhlew .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 15: Consented to extended followup</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Consented">Consented</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr class="

# %%
# gather raw html
raw_html = [f'<div class="page-break">{s}</div>' for s in html_data]
style_css = """
<style>
  .page-break {
    page-break-inside: avoid; /* Always add page break before this element */
  }
  .table-header {
    font-weight: bold;
    font-size: 18px;
    text-align: center;
    border-bottom: None;
  }
</style>
"""
raw_html = ''.join(raw_html)
raw_html = f'<!DOCTYPE html>\n<html lang="en">\n{style_css}\n<head>\n<meta charset="utf-8"/>\n</head>\n<body>\n' + document_title + raw_html + '\n</body>\n</html>\n'

# %%
# render html to PDF
pdfkit.from_string(raw_html, str(analysis_folder / pdf_filename),
options={
    'footer-center': 'Page [page] of [topage]',
    'footer-font-size': '8',
    'footer-spacing': '5',
    'encoding': "UTF-8",
    'margin-top':'10mm',
    'margin-right':'15mm',
    'margin-bottom':'15mm',
    'margin-left':'15mm',
    'header-center': study_title,
    'header-font-size': '6',
    'header-spacing': '0',
    'disable-javascript': None,
    'no-outline': None,
},
verbose=True)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# True
