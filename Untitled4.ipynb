# %%
import pymysql
import pandas as pd

from sqlalchemy import create_engine

sqlEngine = create_engine(
    "mysql+pymysql://root:cc3721b@127.0.0.1:3306/mapitio_production", pool_recycle=3600
)
dbConnection = sqlEngine.connect()

df = pd.read_sql(
    "select * from mapitio_production.mapitio_lists_arvregimens", dbConnection
)
pd.set_option("display.expand_frame_repr", False)
dbConnection.close()

# %%
df[["id","name","display_name"]].to_csv("/Users/erikvw/Documents/lstm/Protocols/mapitio/arv_regimens.csv", float_format='%.1f',index=False)

# %%
df = pd.read_csv("/Users/erikvw/Documents/lstm/Protocols/mapitio/arv_regimens.csv")

# %%
df
# Out:
#     id               name             display_name
# 0    1      TDF_3TC_ATV_r        TDF + 3TC + ATV/r
# 1    2      TDF_FTC_ATV_r        TDF + FTC + ATV/r
# 2    3      TDF_3TC_LPV_r        TDF + 3TC + LPV/r
# 3    4      AZT_3TC_ATV_r        AZT + 3TC + ATV/r
# 4    5      AZT_3TC_LPV_r        AZT + 3TC + LPV/r
# 5    6      ABC_3TC_ATV_r        ABC + 3TC + ATV/r
# 6    7      ABC_3TC_LPV_r        ABC + 3TC + LPV/r
# 7    8      TDF_FTC_LPV_r        TDF + FTC + LPV/r
# 8    9  DTG_ABC/3TC_ATV_r  DTG + (ABC/3TC) + ATV/r
# 9   10                NaN      Not applicable  ---
# 10  11              OTHER       Other, specify ...
# 11  12        AZT_3TC_EFV          AZT + 3TC + EFV
# 12  13        AZT_3TC_NVP          AZT + 3TC + NVP
# 13  14        ZDV_3TC_EFV          ZDV + 3TC + EFV
# 14  15        ZDV_3TC_NVP          ZDV + 3TC + NVP
# 15  16        D4T_3TC_NVP          D4T + 3TC + NVP
# 16  17        TDF_3TC_DTG          TDF + 3TC + DTG
# ...
