# %%
# %%capture
# uv sync --group develop --group lint --group test --group notebook
import os
from pathlib import Path

import numpy as np
import pandas as pd
from dj_notebook import activate
from django_pandas.io import read_frame

env_file = os.environ["META_ENV"]
reports_folder = Path(os.environ["META_REPORTS_FOLDER"])
analysis_folder = Path(os.environ["META_ANALYSIS_FOLDER"])
pharmacy_folder = Path(os.environ["META_PHARMACY_FOLDER"])
plus = activate(dotenv_file=env_file)
pd.set_option('future.no_silent_downcasting', True)

# %%
from collections.abc import Callable
from datetime import date

import pdfkit
from edc_appointment.analytics import get_appointment_df
from edc_appointment.constants import (  # noqa
    CANCELLED_APPT,
    MISSED_APPT,
    NEW_APPT,
    ONTIME_APPT,
    SCHEDULED_APPT,
    UNSCHEDULED_APPT,
)
from edc_constants.constants import YES  # noqa
from edc_pdutils.dataframes import get_subject_visit
from edc_visit_schedule.models import SubjectScheduleHistory
from great_tables import loc, md, style
from scipy.stats import chi2

from meta_analytics.dataframes import (
    GlucoseEndpointsByDate,
    get_eos_df,
    get_glucose_df,
    get_screening_df,
)
from meta_analytics.utils import df_as_great_table, df_as_great_table2
from meta_consent.models import SubjectConsentV1Ext
from meta_prn.models import LossToFollowup
from meta_visit_schedule.constants import (
    MONTH15,
    MONTH18,
    MONTH21,
    MONTH27,
    MONTH30,
    MONTH33,
    MONTH39,
)

# %%
html_data = []
data_download_date = date(2025, 9, 6)
cutoff_date = date(2025, 9, 6)
end_of_trial_date = date(2026, 5, 31)
document_title = f"<h2>Monitoring Report: {cutoff_date.strftime('%B %Y')}</h2><h5>Data Download: {data_download_date.strftime('%d %B %Y')} using cutoff date of {cutoff_date.strftime('%d %B %Y')}</h5>"
study_title = 'META3 - Metformin treatment for diabetes prevention in Africa'
pdf_filename = f"monitoring_report_{cutoff_date.strftime('%Y%m%d')}.pdf"

# %%
# 105-30-0288-5 should also be late excluded based on the haemoglobin 4.8 presented at baseline

df_visit = get_subject_visit("meta_subject.subjectvisit")
df_visit_1691 = df_visit.copy()

late_exlusion_offstudy_reasons = [
    'Patient fulfilled late exclusion criteria (due to abnormal blood values or raised blood pressure at enrolment']
df_eos = get_eos_df()
df_eos_1691 = df_eos.copy()
df_eos_excluded = (
    df_eos
    .query("offstudy_reason.isin(@late_exlusion_offstudy_reasons)")
    .copy()
    .reset_index()
)
df_visit = (
    df_visit
    .merge(df_eos_excluded[["subject_identifier", "offstudy_datetime", "offstudy_reason"]], on="subject_identifier",
           how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
)

df_visit = df_visit[df_visit.appt_datetime.dt.date <= cutoff_date]

df_appointments = get_appointment_df()
df_appointments["site_id"] = df_appointments.site_id.astype(str)
df_appointments_1691 = df_appointments.copy()
df_appointments = (
    df_appointments
    .merge(df_eos_excluded[["subject_identifier", "offstudy_datetime", "offstudy_reason"]], on="subject_identifier",
           how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
)

cls = GlucoseEndpointsByDate()
cls.run()
df_endpoint = cls.endpoint_only_df.copy()
df_glucose = get_glucose_df()
# df_glucose_fbg = get_glucose_fbg_df()
# df_glucose = pd.concat([df_glucose, df_glucose_fbg])


enrolled = df_visit.copy()
enrolled["site_id"] = enrolled["site_id"].astype(str)
enrolled_pivot = (
    enrolled
    .query("visit_code==1000.0").groupby(["site_id"])
    .size()
    .reset_index()
    .pivot_table(columns="site_id", values=0, observed=True)
)
enrolled_pivot.columns.name = ""
enrolled_pivot["total"] = enrolled_pivot[["10", "20", "30", "40", "60"]].sum(axis=1)

# %%
# before late exclusion
df_visit_orig = df_visit_1691[df_visit_1691.appt_datetime.dt.date <= cutoff_date]
enrolled_1691 = df_visit_1691.copy()
enrolled_1691["site_id"] = enrolled_1691["site_id"].astype(str)
enrolled_1691_pivot = (
    enrolled_1691
    .query("visit_code==1000.0").groupby(["site_id"])
    .size()
    .reset_index()
    .pivot_table(columns="site_id", values=0, observed=True)
)
enrolled_1691_pivot.columns.name = ""
enrolled_1691_pivot["total"] = enrolled_1691_pivot[["10", "20", "30", "40", "60"]].sum(axis=1)

# df_eos_1691
# df_appointments_1691

# %%
column_headers = {"label": "Label", "visit_code": "Visit code", "10": "Hindu Mandal", "20": "Amana", "30": "Temeke",
                  "40": "Mwananyamala", "60": "Mnazi Moja", "total": "Total"}
column_headers_with_str = {"label": "Label", "10_str": "Hindu Mandal", "20_str": "Amana", "30_str": "Temeke",
                           "40_str": "Mwananyamala", "60_str": "Mnazi Moja", "total_str": "Total"}

# %%
# Table 1a Visits completed to date

df_tbl1 = df_visit[(df_visit.visit_code_sequence == 0) & (df_visit.appt_timing == ONTIME_APPT) & ~(
    df_visit.appt_status.isin([NEW_APPT, CANCELLED_APPT]))].groupby(
    by=["visit_code", "site_id"]).size().to_frame().reset_index()

df_tbl1.columns = ["visit_code", "site_id", "visits"]
df1 = df_tbl1.pivot(index="visit_code", columns="site_id", values="visits").reset_index()
df1.columns.name = None
df1.columns = ['visit_code', "10", "20", "30", "40", "60"]
df1['total'] = df1[['10', '20', '30', '40', '60']].sum(axis=1)
df1.fillna(0, inplace=True)
df_attended = df1.copy().reset_index(drop=True)
df_attended = df_attended.fillna(0.0)

# %%
gt = df_as_great_table(
    df_attended[["visit_code", "10", "20", "30", "40", "60", "total"]],
    title="Table 1a: Visits completed to date"
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k != "label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .tab_source_note(
        source_note=(
            "Excludes visit reports submitted for participants "
            "eventually withdrawn on late exclusion criteria."
        )
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="jrflnocasb" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #jrflnocasb table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #jrflnocasb thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #jrflnocasb p { margin: 0; padding: 0; }
#  #jrflnocasb .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #jrflnocasb .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #jrflnocasb .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #jrflnocasb .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #jrflnocasb .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jrflnocasb .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #jrflnocasb .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #jrflnocasb .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #jrflnocasb .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #jrflnocasb .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #jrflnocasb .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #jrflnocasb .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #jrflnocasb .gt_spanner_row { border-bottom-style: hidden; }
#  #jrflnocasb .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #jrflnocasb .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #jrflnocasb .gt_from_md> :first-child { margin-top: 0; }
#  #jrflnocasb .gt_from_md> :last-child { margin-bottom: 0; }
#  #jrflnocasb .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #jrflnocasb .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #jrflnocasb .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #jrflnocasb .gt_row_group_first td { border-top-width: 2px; }
#  #jrflnocasb .gt_row_group_first th { border-top-width: 2px; }
#  #jrflnocasb .gt_striped { background-color: #F4F4F4; }
#  #jrflnocasb .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #jrflnocasb .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #jrflnocasb .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #jrflnocasb .gt_left { text-align: left; }
#  #jrflnocasb .gt_center { text-align: center; }
#  #jrflnocasb .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #jrflnocasb .gt_font_normal { font-weight: normal; }
#  #jrflnocasb .gt_font_bold { font-weight: bold; }
#  #jrflnocasb .gt_font_italic { font-style: italic; }
#  #jrflnocasb .gt_super { font-size: 65%; }
#  #jrflnocasb .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #jrflnocasb .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1a: Visits completed to date</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td st

# %%
# Table 1b Total scheduled appointments
df_appt_pivot = (
    df_appointments.query("appt_reason==@SCHEDULED_APPT")
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)

df_appt_pivot["total"] = df_appt_pivot.iloc[:, 1:].sum(axis=1)
df_appt_pivot.columns.name = None
gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1b: Total appointments",
    subtitle="Total possible appointments not including unscheduled appointments"

)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k != "label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="efyvazciav" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #efyvazciav table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #efyvazciav thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #efyvazciav p { margin: 0; padding: 0; }
#  #efyvazciav .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #efyvazciav .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #efyvazciav .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #efyvazciav .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #efyvazciav .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #efyvazciav .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #efyvazciav .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #efyvazciav .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #efyvazciav .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #efyvazciav .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #efyvazciav .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #efyvazciav .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #efyvazciav .gt_spanner_row { border-bottom-style: hidden; }
#  #efyvazciav .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #efyvazciav .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #efyvazciav .gt_from_md> :first-child { margin-top: 0; }
#  #efyvazciav .gt_from_md> :last-child { margin-bottom: 0; }
#  #efyvazciav .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #efyvazciav .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #efyvazciav .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #efyvazciav .gt_row_group_first td { border-top-width: 2px; }
#  #efyvazciav .gt_row_group_first th { border-top-width: 2px; }
#  #efyvazciav .gt_striped { background-color: #F4F4F4; }
#  #efyvazciav .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #efyvazciav .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #efyvazciav .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #efyvazciav .gt_left { text-align: left; }
#  #efyvazciav .gt_center { text-align: center; }
#  #efyvazciav .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #efyvazciav .gt_font_normal { font-weight: normal; }
#  #efyvazciav .gt_font_bold { font-weight: bold; }
#  #efyvazciav .gt_font_italic { font-style: italic; }
#  #efyvazciav .gt_super { font-size: 65%; }
#  #efyvazciav .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #efyvazciav .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1b: Total appointments</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Total possible appointments not including unscheduled appointments</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>

# %%
# Table 1c Past scheduled appointments -- no information provided
df_appt_pivot = (
    df_appointments.query(
        "appt_datetime<@cutoff_date and appt_reason==@SCHEDULED_APPT and appt_timing==@ONTIME_APPT and appt_status.isin([@NEW_APPT])")
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)
df_appt_pivot["total"] = df_appt_pivot.iloc[:, 1:].sum(axis=1)
df_appt_pivot.columns.name = None
gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1c: Past appointments not attended/not reported",
    subtitle="Expected by now but no information provided by site",
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k != "label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .tab_source_note(source_note=f"Scheduled appointment date is before {cutoff_date.strftime('%d %B %Y')}.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="ndobywrnub" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ndobywrnub table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ndobywrnub thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ndobywrnub p { margin: 0; padding: 0; }
#  #ndobywrnub .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ndobywrnub .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ndobywrnub .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #ndobywrnub .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #ndobywrnub .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ndobywrnub .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ndobywrnub .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ndobywrnub .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ndobywrnub .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ndobywrnub .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ndobywrnub .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ndobywrnub .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ndobywrnub .gt_spanner_row { border-bottom-style: hidden; }
#  #ndobywrnub .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ndobywrnub .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #ndobywrnub .gt_from_md> :first-child { margin-top: 0; }
#  #ndobywrnub .gt_from_md> :last-child { margin-bottom: 0; }
#  #ndobywrnub .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #ndobywrnub .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #ndobywrnub .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ndobywrnub .gt_row_group_first td { border-top-width: 2px; }
#  #ndobywrnub .gt_row_group_first th { border-top-width: 2px; }
#  #ndobywrnub .gt_striped { background-color: #F4F4F4; }
#  #ndobywrnub .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ndobywrnub .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ndobywrnub .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ndobywrnub .gt_left { text-align: left; }
#  #ndobywrnub .gt_center { text-align: center; }
#  #ndobywrnub .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ndobywrnub .gt_font_normal { font-weight: normal; }
#  #ndobywrnub .gt_font_bold { font-weight: bold; }
#  #ndobywrnub .gt_font_italic { font-style: italic; }
#  #ndobywrnub .gt_super { font-size: 65%; }
#  #ndobywrnub .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ndobywrnub .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1c: Past appointments not attended/not reported</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Expected by now but no information provided by site</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi M

# %%
# Table 1d Unscheduled appointments
df_appt = (
    df_appointments.query("appt_reason==@UNSCHEDULED_APPT and appt_timing==@ONTIME_APPT and appt_status!=@NEW_APPT")
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .copy()
    .reset_index(drop=True)
)
df_appt['visit_code'] = df_appt['visit_code'].astype(int)
df_appt['visit_code'] = df_appt['visit_code'].astype(str)

subjects_with_unscheduled = df_appt.subject_identifier.nunique()

df_appt_pivot = (
    df_appt
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)
df_appt_pivot["total"] = df_appt_pivot.iloc[:, 1:].sum(axis=1)
df_appt_pivot.columns.name = None
df_appt_pivot[["10", "20", "30", "40", "60", "total"]] = df_appt_pivot[["10", "20", "30", "40", "60", "total"]].astype(
    'float64')

# add totals row
sum_row = df_appt_pivot.select_dtypes(include='float64').sum()
sum_row['visit_code'] = 'Total'
sum_row_df = pd.DataFrame(sum_row).T
df_appt_pivot = pd.concat([df_appt_pivot, sum_row_df], axis=0).reset_index(drop=True)

gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1d: Unscheduled appointments",
    subtitle="Appointments with sequence>0 grouped by visit code",
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k != "label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .fmt_number(columns=["10", "20", "30", "40", "60", "total"], decimals=0)
    .tab_source_note(source_note=f"{subjects_with_unscheduled} participants had at least one unscheduled appointment.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="ociapdhsfw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ociapdhsfw table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ociapdhsfw thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ociapdhsfw p { margin: 0; padding: 0; }
#  #ociapdhsfw .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ociapdhsfw .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ociapdhsfw .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #ociapdhsfw .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #ociapdhsfw .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ociapdhsfw .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ociapdhsfw .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ociapdhsfw .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ociapdhsfw .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ociapdhsfw .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ociapdhsfw .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ociapdhsfw .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ociapdhsfw .gt_spanner_row { border-bottom-style: hidden; }
#  #ociapdhsfw .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ociapdhsfw .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #ociapdhsfw .gt_from_md> :first-child { margin-top: 0; }
#  #ociapdhsfw .gt_from_md> :last-child { margin-bottom: 0; }
#  #ociapdhsfw .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #ociapdhsfw .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #ociapdhsfw .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ociapdhsfw .gt_row_group_first td { border-top-width: 2px; }
#  #ociapdhsfw .gt_row_group_first th { border-top-width: 2px; }
#  #ociapdhsfw .gt_striped { background-color: #F4F4F4; }
#  #ociapdhsfw .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ociapdhsfw .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ociapdhsfw .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ociapdhsfw .gt_left { text-align: left; }
#  #ociapdhsfw .gt_center { text-align: center; }
#  #ociapdhsfw .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ociapdhsfw .gt_font_normal { font-weight: normal; }
#  #ociapdhsfw .gt_font_bold { font-weight: bold; }
#  #ociapdhsfw .gt_font_italic { font-style: italic; }
#  #ociapdhsfw .gt_super { font-size: 65%; }
#  #ociapdhsfw .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ociapdhsfw .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1d: Unscheduled appointments</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Appointments with sequence&gt;0 grouped by visit code</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th cl

# %%
# Table 1e Future scheduled appointments
df_appt_pivot = (
    df_appointments.query(
        "@cutoff_date<=appt_datetime<@end_of_trial_date and appt_reason==@SCHEDULED_APPT and appt_timing==@ONTIME_APPT and appt_status.isin([@NEW_APPT])")
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .groupby(["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
    .pivot(index="visit_code", columns="site_id", values=0)
    .reset_index()
    .fillna(0)
)
df_appt_pivot["total"] = df_appt_pivot.iloc[:, 1:].sum(axis=1)
df_appt_pivot.columns.name = None
gt = df_as_great_table(
    df_appt_pivot,
    title="Table 1e: Future appointments",
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k != "label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code"])
    .data_color(
        columns=["visit_code"],
        palette=["lavender", "thistle"],
        domain=[2000, 5000],
        na_color="white"
    )
    .fmt_number(columns=["10", "20", "30", "40", "60", "total"], decimals=0)
    .tab_source_note(
        source_note=f"Scheduled appointment date is on or after {cutoff_date.strftime('%d %B %Y')} and before {end_of_trial_date.strftime('%d %B %Y')}.")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="aujygisfug" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #aujygisfug table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #aujygisfug thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #aujygisfug p { margin: 0; padding: 0; }
#  #aujygisfug .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #aujygisfug .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #aujygisfug .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #aujygisfug .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #aujygisfug .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #aujygisfug .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #aujygisfug .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #aujygisfug .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #aujygisfug .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #aujygisfug .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #aujygisfug .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #aujygisfug .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #aujygisfug .gt_spanner_row { border-bottom-style: hidden; }
#  #aujygisfug .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #aujygisfug .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #aujygisfug .gt_from_md> :first-child { margin-top: 0; }
#  #aujygisfug .gt_from_md> :last-child { margin-bottom: 0; }
#  #aujygisfug .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #aujygisfug .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #aujygisfug .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #aujygisfug .gt_row_group_first td { border-top-width: 2px; }
#  #aujygisfug .gt_row_group_first th { border-top-width: 2px; }
#  #aujygisfug .gt_striped { background-color: #F4F4F4; }
#  #aujygisfug .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #aujygisfug .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #aujygisfug .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #aujygisfug .gt_left { text-align: left; }
#  #aujygisfug .gt_center { text-align: center; }
#  #aujygisfug .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #aujygisfug .gt_font_normal { font-weight: normal; }
#  #aujygisfug .gt_font_bold { font-weight: bold; }
#  #aujygisfug .gt_font_italic { font-style: italic; }
#  #aujygisfug .gt_super { font-size: 65%; }
#  #aujygisfug .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #aujygisfug .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 1e: Future appointments</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td style="

# %%
# Table 2 Visits Missed to Date as % of Visits Attended + Visits Missed
subject_count = (
    df_visit
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .query("visit_code_sequence==0 and appt_timing==@MISSED_APPT and ~appt_status.isin([@NEW_APPT, @CANCELLED_APPT])")
).subject_identifier.nunique()
df_tbl = (
    df_visit[(df_visit.visit_code_sequence == 0) & (df_visit.appt_timing == MISSED_APPT) & ~(
        df_visit.appt_status.isin([NEW_APPT, CANCELLED_APPT]))]
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .groupby(by=["visit_code", "site_id"])
    .size()
    .to_frame()
    .reset_index()
)
df_tbl.columns = ["visit_code", "site_id", "visits"]
df_tbl_pivot = df_tbl.pivot(index="visit_code", columns="site_id", values="visits").reset_index()
df_tbl_pivot.columns.name = None
df_tbl_pivot.columns = ['visit_code', "10", "20", "30", "40", "60"]
df_tbl_pivot['total'] = df_tbl_pivot[['10', '20', '30', '40', '60']].sum(axis=1)
df_missed = (
    df_tbl_pivot
    .fillna(0)
    .copy()
    .set_index(["visit_code"])
)

df_attended_display = df_attended.copy()
df_attended_display = (
    df_attended_display
    .set_index(["visit_code"])
)

attended_and_missed = df_attended_display + df_missed
attended_and_missed = (
    attended_and_missed
    .fillna(0)
    .reset_index()
    .set_index(["visit_code"])
)

attended_and_missed_perc = df_missed / attended_and_missed
attended_and_missed_perc = (
    attended_and_missed_perc
    .fillna(0)
    .reset_index()
    .set_index(["visit_code"])
)

df_result = df_missed.merge(attended_and_missed_perc, on=["visit_code"], suffixes=("", "_perc"))
for col in ["10", "20", "30", "40", "60", "total"]:
    col_perc = f"{col}_perc"
    df_result[col] = df_result.apply(lambda x: f"{x[col]} ({x[col_perc] * 100:.2f})", axis=1)
df_result = df_result.reset_index().sort_values(by=["visit_code"], ascending=True)
df_result = df_result.fillna(0.0)

# %%
df_table = df_result[["visit_code", "10", "20", "30", "40", "60", "total"]].copy()
gt = df_as_great_table(
    df_table,
    title="Table 2a: Visits Missed to Date",
    subtitle="as % of Visits Attended + Visits Missed"
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k != "label"})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["visit_code", "label"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=list(range(0, len(df_table))),
        ),
    )
    .tab_source_note(source_note=f"{subject_count} participants had at least one missed visit.")

)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="yvvknphvbl" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #yvvknphvbl table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #yvvknphvbl thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #yvvknphvbl p { margin: 0; padding: 0; }
#  #yvvknphvbl .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #yvvknphvbl .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #yvvknphvbl .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #yvvknphvbl .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #yvvknphvbl .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #yvvknphvbl .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #yvvknphvbl .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #yvvknphvbl .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #yvvknphvbl .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #yvvknphvbl .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #yvvknphvbl .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #yvvknphvbl .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #yvvknphvbl .gt_spanner_row { border-bottom-style: hidden; }
#  #yvvknphvbl .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #yvvknphvbl .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #yvvknphvbl .gt_from_md> :first-child { margin-top: 0; }
#  #yvvknphvbl .gt_from_md> :last-child { margin-bottom: 0; }
#  #yvvknphvbl .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #yvvknphvbl .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #yvvknphvbl .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #yvvknphvbl .gt_row_group_first td { border-top-width: 2px; }
#  #yvvknphvbl .gt_row_group_first th { border-top-width: 2px; }
#  #yvvknphvbl .gt_striped { background-color: #F4F4F4; }
#  #yvvknphvbl .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #yvvknphvbl .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #yvvknphvbl .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #yvvknphvbl .gt_left { text-align: left; }
#  #yvvknphvbl .gt_center { text-align: center; }
#  #yvvknphvbl .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #yvvknphvbl .gt_font_normal { font-weight: normal; }
#  #yvvknphvbl .gt_font_bold { font-weight: bold; }
#  #yvvknphvbl .gt_font_italic { font-style: italic; }
#  #yvvknphvbl .gt_super { font-size: 65%; }
#  #yvvknphvbl .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #yvvknphvbl .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 2a: Visits Missed to Date</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">as % of Visits Attended + Visits Missed</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="visit_code">Visit code</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_headi

# %%
# Table 2b: Number of missed visits by participant
subject_count = (
    df_visit
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .query("visit_code_sequence==0 and appt_timing==@MISSED_APPT and ~appt_status.isin([@NEW_APPT, @CANCELLED_APPT])")
).subject_identifier.nunique()
df_tbl = (
    df_visit[(df_visit.visit_code_sequence == 0) & (df_visit.appt_timing == MISSED_APPT) & ~(
        df_visit.appt_status.isin([NEW_APPT, CANCELLED_APPT]))]
    .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", indicator=True)
    .query("_merge=='left_only'")
    .drop(columns=["_merge"])
    .reset_index(drop=True)
    .groupby(by=["subject_identifier", "site_id"])
    .size()
    .to_frame()
    .reset_index()
)
df_tbl.columns = ["subject_identifier", "site_id", "missed_count"]
df_tbl["category"] = pd.cut(df_tbl["missed_count"], bins=[0, 1, 3, 5, 7, 100],
                            labels=["Missed at least 1", "2 to 3", "4 to 5", "6 to 7", "missed more than 7"])
df_tbl_pivot = df_tbl.pivot_table(index="category", columns="site_id", values="missed_count", observed=False,
                                  aggfunc="count").reset_index()

df_tbl_pivot['total'] = df_tbl_pivot.select_dtypes(include='int').sum(axis=1, skipna=True)

sum_row = df_tbl_pivot.select_dtypes(include='int64').sum()
sum_row['category'] = 'Total'

df_tbl_pivot = (
    pd.concat([df_tbl_pivot, sum_row.to_frame().T], axis=0)
    .rename(columns={10: "10", 20: "20", 30: "30", 40: "40", 60: "60"})
)

gt = df_as_great_table(
    df_tbl_pivot,
    title="Table 2b: Number of participants who missed one or more visits",
)
gt = (
    gt
    .cols_label(
        {"category": "Category", **{k: v for k, v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["category"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=list(range(0, len(df_table))),
        ),
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="anobtbqdnt" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #anobtbqdnt table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #anobtbqdnt thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #anobtbqdnt p { margin: 0; padding: 0; }
#  #anobtbqdnt .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #anobtbqdnt .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #anobtbqdnt .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #anobtbqdnt .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #anobtbqdnt .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #anobtbqdnt .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #anobtbqdnt .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #anobtbqdnt .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #anobtbqdnt .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #anobtbqdnt .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #anobtbqdnt .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #anobtbqdnt .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #anobtbqdnt .gt_spanner_row { border-bottom-style: hidden; }
#  #anobtbqdnt .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #anobtbqdnt .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #anobtbqdnt .gt_from_md> :first-child { margin-top: 0; }
#  #anobtbqdnt .gt_from_md> :last-child { margin-bottom: 0; }
#  #anobtbqdnt .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #anobtbqdnt .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #anobtbqdnt .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #anobtbqdnt .gt_row_group_first td { border-top-width: 2px; }
#  #anobtbqdnt .gt_row_group_first th { border-top-width: 2px; }
#  #anobtbqdnt .gt_striped { background-color: #F4F4F4; }
#  #anobtbqdnt .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #anobtbqdnt .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #anobtbqdnt .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #anobtbqdnt .gt_left { text-align: left; }
#  #anobtbqdnt .gt_center { text-align: center; }
#  #anobtbqdnt .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #anobtbqdnt .gt_font_normal { font-weight: normal; }
#  #anobtbqdnt .gt_font_bold { font-weight: bold; }
#  #anobtbqdnt .gt_font_italic { font-style: italic; }
#  #anobtbqdnt .gt_super { font-size: 65%; }
#  #anobtbqdnt .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #anobtbqdnt .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 2b: Number of participants who missed one or more visits</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="category">Category</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_

# %%
# func for tables 3,4,5
def get_row_df(row_df: pd.DataFrame, label: str = None, **kwargs) -> pd.DataFrame:
    row_df = row_df.groupby(by=["site_id"]).site_id.count().to_frame(name="n")
    row_df["label"] = label
    row_df = row_df.reset_index()
    row_df = row_df.pivot(index="label", values="n", columns="site_id").reset_index()
    row_df.columns.name = ""
    all_sites = [10, 20, 30, 40, 60]
    for site in all_sites:
        if site not in row_df.columns:
            row_df[site] = None
    row_df = row_df.reset_index(drop=True)
    return row_df


def get_table_df(
        df_source: pd.DataFrame,
        visit_code: float | None = None,
        month_label: str | None = None,
        visit_codes: list[float] | None = None,
        get_row_func: Callable | None = None,
        category_labels: list[str] | None = None,
) -> pd.DataFrame:
    get_row_df_func = get_row_func or get_row_df
    if visit_code:
        df_month = df_source[df_source.visit_code == visit_code].copy()
    elif visit_codes:
        df_month = df_source[df_source.visit_code.isin(visit_codes)].copy()
    elif month_label:
        df_month = df_source.copy()

    row_df = df_month.copy()
    table_df = get_row_df_func(row_df, "Total (n)", category_labels=category_labels)

    row_df = df_month.query("ogtt_value<7.8 and fbg_value<6.1").copy()
    table_df = pd.concat([table_df, get_row_df_func(row_df, "OGTT <7.8; FBG <6.1", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value < 7.8) & (df_month.fbg_value >= 6.1) & (df_month.fbg_value < 7.0)].copy()
    table_df = pd.concat(
        [table_df, get_row_df_func(row_df, "OGTT <7.8; FBG >=6.1 <7.0", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value < 7.8) & (df_month.fbg_value >= 7.0)].copy()
    table_df = pd.concat([table_df, get_row_df_func(row_df, "OGTT <7.8; FBG >=7.0", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value >= 7.8) & (df_month.ogtt_value < 11.1) & (df_month.fbg_value < 6.1)].copy()
    table_df = pd.concat(
        [table_df, get_row_df_func(row_df, "OGTT ≥7.8 to <11.1; FBG <6.1", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value >= 7.8) & (df_month.ogtt_value < 11.1) & (df_month.fbg_value >= 6.1) & (
            df_month.fbg_value < 7.0)].copy()
    table_df = pd.concat(
        [table_df, get_row_df_func(row_df, "OGTT ≥7.8 to <11.1; FBG >=6.1 <7.0", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value >= 7.8) & (df_month.ogtt_value < 11.1) & (df_month.fbg_value >= 7.0)].copy()
    table_df = pd.concat(
        [table_df, get_row_df_func(row_df, "OGTT ≥7.8 to <11.1; FBG >=7.0", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value >= 11.1) & (df_month.fbg_value < 6.1)].copy()
    table_df = pd.concat([table_df, get_row_df_func(row_df, "OGTT ≥11.1; FBG <6.1", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value >= 11.1) & (df_month.fbg_value >= 6.1) & (df_month.fbg_value < 7.0)].copy()
    table_df = pd.concat(
        [table_df, get_row_df_func(row_df, "OGTT ≥11.1; FBG >=6.1 <7.0", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value >= 11.1) & (df_month.fbg_value >= 7.0)].copy()
    table_df = pd.concat([table_df, get_row_df_func(row_df, "OGTT ≥11.1; FBG >=7.0", category_labels=category_labels)])

    row_df = df_month[(df_month.ogtt_value.isna())].copy()
    table_df = pd.concat([table_df, get_row_df_func(row_df, "Missing OGTT", category_labels=category_labels)])
    return table_df


def format_table_df(tbl_df, add_totals: bool | None = None):
    """Pivot on site"""
    add_totals = True if add_totals is None else add_totals
    tbl_df = tbl_df.fillna(0.0)
    tbl_df["total"] = tbl_df.iloc[:, 1:].sum(axis=1)
    tbl_df = tbl_df.reset_index(drop=True)

    if add_totals:
        df_last = tbl_df[1:].sum().to_frame()
        df_last.loc["label"] = np.nan
        df_last = df_last.reset_index()
        df_last.columns = ["label", "value"]
        df_last = df_last.pivot_table(columns="label", values="value").reset_index(drop=True)
        df_last.columns.name = ""
        df_last["label"] = "Totals"

        tbl_df = pd.concat([tbl_df, df_last])
        tbl_df = tbl_df.reset_index(drop=True)

    tbl_df.columns = ["label", "10", "20", "30", "40", "60", "total"]

    for site in ["10", "20", "30", "40", "60", "total"]:
        tbl_df[f"{site}_perc"] = (tbl_df[site] / tbl_df.iloc[0][site]) * 100 if tbl_df.iloc[0][site] > 0 else 0
        tbl_df[f"{site}_perc_str"] = tbl_df[f"{site}_perc"].map('{:.1f}'.format)

    for site in ["10", "20", "30", "40", "60", "total"]:
        tbl_df[f"{site}_str"] = tbl_df[[f"{site}", f"{site}_perc_str"]].apply(lambda x: ' ('.join(x.astype(str)),
                                                                              axis=1)
        tbl_df[f"{site}_str"] = tbl_df[f"{site}_str"] + ")"

    cols = ["label", *[f"{site}_str" for site in ["10", "20", "30", "40", "60", "total"]]]
    tbl_df1 = tbl_df[cols]
    tbl_df1.loc[tbl_df.label == "Total (n)"] = tbl_df.iloc[0][
        ["label", "10", "20", "30", "40", "60", "total"]].to_list()
    return tbl_df1


def format_table_with_bmi_df(tbl_df, add_totals: bool | None = None, category_labels: list[str] = None):
    """Pivot on BMI categories"""

    add_totals = True if add_totals is None else add_totals
    tbl_df = tbl_df.fillna(0.0)
    tbl_df["total"] = tbl_df.iloc[:, 1:].sum(axis=1)
    tbl_df = tbl_df.reset_index(drop=True)

    if add_totals:
        df_last = tbl_df[1:].sum().to_frame()
        df_last.loc["label"] = np.nan
        df_last = df_last.reset_index()
        df_last.columns = ["label", "value"]
        df_last = df_last.pivot_table(columns="label", values="value").reset_index(drop=True)
        df_last.columns.name = ""
        df_last["label"] = "Totals"

        tbl_df = pd.concat([tbl_df, df_last])
        tbl_df = tbl_df.reset_index(drop=True)

    tbl_df.columns = ["label", *category_labels, "total"]

    for label in [*category_labels, "total"]:
        tbl_df[f"{label}_perc"] = (tbl_df[label] / tbl_df.iloc[0][label]) * 100 if tbl_df.iloc[0][label] > 0 else 0
        tbl_df[f"{label}_perc_str"] = tbl_df[f"{label}_perc"].map('{:.1f}'.format)

    for cat in [*category_labels, "total"]:
        tbl_df[f"{label}_str"] = tbl_df[[f"{label}", f"{label}_perc_str"]].apply(lambda x: ' ('.join(x.astype(str)),
                                                                                 axis=1)
        tbl_df[f"{label}_str"] = tbl_df[f"{label}_str"] + ")"

    cols = ["label", *[f"{label}_str" for label in [*category_labels, "total"]]]
    tbl_df1 = tbl_df[cols]
    tbl_df1.loc[tbl_df.label == "Total (n)"] = tbl_df.iloc[0][["label", *category_labels, "total"]].to_list()
    return tbl_df1


def get_row_by_df(row_df: pd.DataFrame, label: str, category_labels: list[str]) -> pd.DataFrame:
    # if label not in category_labels:
    #     raise ValueError(f"Invalid label. Expected one of {category_labels}. Got {label}.")
    row_df = row_df.groupby(by=["site_id"]).site_id.count().to_frame(name="n")
    row_df["label"] = label
    row_df = row_df.reset_index()
    row_df = row_df.pivot(index="label", values="n", columns="site_id").reset_index()
    row_df.columns.name = ""

    for label in category_labels:
        if label not in row_df.columns:
            row_df[label] = None
    row_df = row_df.reset_index(drop=True)
    return row_df

# %%
def get_fbg_value(r):
    if not pd.isna(r["converted_fbg2_value"]):
        return r["converted_fbg2_value"]
    return r["converted_fbg_value"]


def get_ogtt_value(r):
    if not pd.isna(r["converted_ogtt2_value"]):
        return r["converted_ogtt2_value"]
    return r["converted_ogtt_value"]

# %%
# Table 3: OGTT and FBG at Enrolment

subjects = df_visit.subject_identifier.unique()
df_screening = get_screening_df().query("consented==True and subject_identifier.isin(@subjects)")
df_screening["visit_code"] = "Enrol"
df_screening["fbg_value"] = df_screening.apply(get_fbg_value, axis=1)
df_screening["ogtt_value"] = df_screening.apply(get_ogtt_value, axis=1)
df_screening["site_id"] = df_screening.site.astype(int)
df_screening = df_screening.drop(columns=["site"])
df_table3 = get_table_df(df_screening, month_label="enrol")
df_table3 = format_table_df(df_table3)
df_table3 = df_table3.fillna(0.0)
gt = df_as_great_table(df_table3, title="Table 3a: OGTT and FBG at Screening / Enrolment")

column_headers_enrol = {k: v for k, v in column_headers_with_str.items() if k not in "visit_code"}
gt = (
    gt
    .cols_label(column_headers_enrol)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
    .tab_source_note(source_note="Excluding patients eventually withdrawn for `late exclusion` criteria")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="epuymieann" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #epuymieann table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #epuymieann thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #epuymieann p { margin: 0; padding: 0; }
#  #epuymieann .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #epuymieann .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #epuymieann .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #epuymieann .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #epuymieann .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #epuymieann .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #epuymieann .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #epuymieann .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #epuymieann .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #epuymieann .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #epuymieann .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #epuymieann .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #epuymieann .gt_spanner_row { border-bottom-style: hidden; }
#  #epuymieann .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #epuymieann .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #epuymieann .gt_from_md> :first-child { margin-top: 0; }
#  #epuymieann .gt_from_md> :last-child { margin-bottom: 0; }
#  #epuymieann .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #epuymieann .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #epuymieann .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #epuymieann .gt_row_group_first td { border-top-width: 2px; }
#  #epuymieann .gt_row_group_first th { border-top-width: 2px; }
#  #epuymieann .gt_striped { background-color: #F4F4F4; }
#  #epuymieann .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #epuymieann .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #epuymieann .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #epuymieann .gt_left { text-align: left; }
#  #epuymieann .gt_center { text-align: center; }
#  #epuymieann .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #epuymieann .gt_font_normal { font-weight: normal; }
#  #epuymieann .gt_font_bold { font-weight: bold; }
#  #epuymieann .gt_font_italic { font-style: italic; }
#  #epuymieann .gt_super { font-size: 65%; }
#  #epuymieann .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #epuymieann .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 3a: OGTT and FBG at Screening / Enrolment</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="

# %%
# bmi_categories:
#     1 calculated_bmi_value<25
#     2 calculated_bmi_value>=25 & calculated_bmi_value<30
#     3 calculated_bmi_value>=30


# subjects = df_visit.subject_identifier.unique()
# df_screening = get_screening_df().query("consented==True and subject_identifier.isin(@subjects)")
# df_screening["visit_code"] = "Enrol"
# df_screening["fbg_value"] = df_screening.apply(get_fbg_value, axis=1)
# df_screening["ogtt_value"] = df_screening.apply(get_ogtt_value, axis=1)
# df_screening["site_id"] = df_screening.site.astype(int)
# df_screening = df_screening.drop(columns=["site"])
# df_screening["bmi"] = pd.NA
# df_screening.loc[df_screening["calculated_bmi_value"] < 25.0, "bmi"] = "bmi<25"
# df_screening.loc[(df_screening["calculated_bmi_value"]>=25.0) & (df_screening["calculated_bmi_value"] < 30.0), "bmi"] = "25<=bmi<30"
# df_screening.loc[df_screening["calculated_bmi_value"] > 30.0, "bmi"] = "bmi>30"
#
# category_labels = [ "bmi<25", "25<=bmi<30", "bmi>=30", "Total (n)"]
# df_table3 = get_table_df(df_screening, month_label="enrol", get_row_func=get_row_by_df, category_labels=category_labels)
# df_table3 = format_table_with_bmi_df(df_table3, category_labels=category_labels)
# df_table3 = df_table3.fillna(0.0)
# gt = df_as_great_table(df_table3, title="Table 3b: OGTT/FBG by BMI at Screening / Enrolment")
# column_headers_enrol = {"bmi<25_str":"bmi<25", "25<=bmi<30_str":"25<=bmi<30", "bmi>30_str":"bmi>30", "total_str": "total"}
# gt = (
#     gt
#     .cols_label(column_headers_enrol)
#     .cols_align(align="center", columns=["bmi<25_str", "25<=bmi<30_str", "bmi>30_str", "total_str"])
#     .cols_align(align="left", columns=["label"])
#     .cols_width(cases={"label": "35%"})
#     .tab_source_note(source_note="Excluding patients eventually withdrawn for `late exclusion` criteria")
# )
# html_data.append(gt.as_raw_html())
# gt.show()

# %%
[col for col in df_screening.columns if "bmi" in col]
# Out:
# ['calculated_bmi_value']

# %%
# Table 4: OGTT and FBG at 12-month visit
df_table3 = get_table_df(df_glucose, visit_codes=[1120.0])
df_table3 = format_table_df(df_table3)
df_table3 = df_table3.fillna(0.0)
gt = df_as_great_table(df_table3, title="Table 4: OGTT and FBG at 12-month visit")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="ztzoxlcnxo" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ztzoxlcnxo table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ztzoxlcnxo thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ztzoxlcnxo p { margin: 0; padding: 0; }
#  #ztzoxlcnxo .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ztzoxlcnxo .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ztzoxlcnxo .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #ztzoxlcnxo .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #ztzoxlcnxo .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ztzoxlcnxo .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ztzoxlcnxo .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ztzoxlcnxo .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ztzoxlcnxo .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ztzoxlcnxo .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ztzoxlcnxo .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ztzoxlcnxo .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ztzoxlcnxo .gt_spanner_row { border-bottom-style: hidden; }
#  #ztzoxlcnxo .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ztzoxlcnxo .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #ztzoxlcnxo .gt_from_md> :first-child { margin-top: 0; }
#  #ztzoxlcnxo .gt_from_md> :last-child { margin-bottom: 0; }
#  #ztzoxlcnxo .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #ztzoxlcnxo .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #ztzoxlcnxo .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ztzoxlcnxo .gt_row_group_first td { border-top-width: 2px; }
#  #ztzoxlcnxo .gt_row_group_first th { border-top-width: 2px; }
#  #ztzoxlcnxo .gt_striped { background-color: #F4F4F4; }
#  #ztzoxlcnxo .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ztzoxlcnxo .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ztzoxlcnxo .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ztzoxlcnxo .gt_left { text-align: left; }
#  #ztzoxlcnxo .gt_center { text-align: center; }
#  #ztzoxlcnxo .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ztzoxlcnxo .gt_font_normal { font-weight: normal; }
#  #ztzoxlcnxo .gt_font_bold { font-weight: bold; }
#  #ztzoxlcnxo .gt_font_italic { font-style: italic; }
#  #ztzoxlcnxo .gt_super { font-size: 65%; }
#  #ztzoxlcnxo .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ztzoxlcnxo .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 4: OGTT and FBG at 12-month visit</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_h

# %%
df_glucose.query("visit_code==1360.0 and ogtt_value.isna()")[["subject_identifier", "site_id"]].set_index("subject_identifier")
# Out:
#                     site_id
# subject_identifier
# 105-10-0024-6            10
# 105-10-0031-1            10
# 105-10-0033-7            10
# 105-10-0044-4            10
# 105-10-0057-6            10
# 105-20-0157-3            20
# 105-20-0166-4            20
# 105-30-0005-3            30
# 105-30-0024-4            30
# 105-30-0051-7            30
# 105-30-0067-3            30
# 105-30-0098-8            30
# 105-40-0069-8            40
# 105-40-0073-0            40
# 105-60-0002-7            60
# 105-60-0018-3            60
# 105-60-0019-1            60

# %%
# Table 5: OGTT and FBG at 24-month visit
df_table4 = get_table_df(df_glucose, 1240.0)
df_table4 = format_table_df(df_table4)
df_table4 = df_table4.fillna(0.0)
gt = df_as_great_table(df_table4, title="Table 5: OGTT and FBG at 24-month visit")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="rhfrhwaxlw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #rhfrhwaxlw table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #rhfrhwaxlw thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #rhfrhwaxlw p { margin: 0; padding: 0; }
#  #rhfrhwaxlw .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #rhfrhwaxlw .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #rhfrhwaxlw .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #rhfrhwaxlw .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #rhfrhwaxlw .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rhfrhwaxlw .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #rhfrhwaxlw .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rhfrhwaxlw .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #rhfrhwaxlw .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #rhfrhwaxlw .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #rhfrhwaxlw .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #rhfrhwaxlw .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #rhfrhwaxlw .gt_spanner_row { border-bottom-style: hidden; }
#  #rhfrhwaxlw .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #rhfrhwaxlw .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #rhfrhwaxlw .gt_from_md> :first-child { margin-top: 0; }
#  #rhfrhwaxlw .gt_from_md> :last-child { margin-bottom: 0; }
#  #rhfrhwaxlw .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #rhfrhwaxlw .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #rhfrhwaxlw .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #rhfrhwaxlw .gt_row_group_first td { border-top-width: 2px; }
#  #rhfrhwaxlw .gt_row_group_first th { border-top-width: 2px; }
#  #rhfrhwaxlw .gt_striped { background-color: #F4F4F4; }
#  #rhfrhwaxlw .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #rhfrhwaxlw .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rhfrhwaxlw .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rhfrhwaxlw .gt_left { text-align: left; }
#  #rhfrhwaxlw .gt_center { text-align: center; }
#  #rhfrhwaxlw .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #rhfrhwaxlw .gt_font_normal { font-weight: normal; }
#  #rhfrhwaxlw .gt_font_bold { font-weight: bold; }
#  #rhfrhwaxlw .gt_font_italic { font-style: italic; }
#  #rhfrhwaxlw .gt_super { font-size: 65%; }
#  #rhfrhwaxlw .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #rhfrhwaxlw .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 5: OGTT and FBG at 24-month visit</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_h

# %%
# Table 6: OGTT and FBG at 36-month visit
df_table5 = get_table_df(df_glucose, 1360.0)
df_table5 = format_table_df(df_table5)
df_table5 = df_table5.fillna(0.0)
gt = df_as_great_table(df_table5, title="Table 6: OGTT and FBG at 36-month visit")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="khmootvlwy" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #khmootvlwy table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #khmootvlwy thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #khmootvlwy p { margin: 0; padding: 0; }
#  #khmootvlwy .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #khmootvlwy .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #khmootvlwy .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #khmootvlwy .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #khmootvlwy .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #khmootvlwy .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #khmootvlwy .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #khmootvlwy .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #khmootvlwy .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #khmootvlwy .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #khmootvlwy .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #khmootvlwy .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #khmootvlwy .gt_spanner_row { border-bottom-style: hidden; }
#  #khmootvlwy .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #khmootvlwy .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #khmootvlwy .gt_from_md> :first-child { margin-top: 0; }
#  #khmootvlwy .gt_from_md> :last-child { margin-bottom: 0; }
#  #khmootvlwy .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #khmootvlwy .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #khmootvlwy .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #khmootvlwy .gt_row_group_first td { border-top-width: 2px; }
#  #khmootvlwy .gt_row_group_first th { border-top-width: 2px; }
#  #khmootvlwy .gt_striped { background-color: #F4F4F4; }
#  #khmootvlwy .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #khmootvlwy .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #khmootvlwy .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #khmootvlwy .gt_left { text-align: left; }
#  #khmootvlwy .gt_center { text-align: center; }
#  #khmootvlwy .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #khmootvlwy .gt_font_normal { font-weight: normal; }
#  #khmootvlwy .gt_font_bold { font-weight: bold; }
#  #khmootvlwy .gt_font_italic { font-style: italic; }
#  #khmootvlwy .gt_super { font-size: 65%; }
#  #khmootvlwy .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #khmootvlwy .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 6: OGTT and FBG at 36-month visit</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_h

# %%
# Table 7: Any OGTT>11.1 ever
row_df = df_glucose[df_glucose.ogtt_value >= 11.1].copy()
table_df = get_row_df(row_df, "Total (n)")
df_table6 = format_table_df(table_df)
df_table = df_table6[:1].fillna(0.0).copy().reset_index(drop=True)
gt = df_as_great_table(df_table, title="Table 7: Any OGTT>11.1 ever")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "35%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="tjtoniyglh" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #tjtoniyglh table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #tjtoniyglh thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #tjtoniyglh p { margin: 0; padding: 0; }
#  #tjtoniyglh .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #tjtoniyglh .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #tjtoniyglh .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #tjtoniyglh .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #tjtoniyglh .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #tjtoniyglh .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #tjtoniyglh .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #tjtoniyglh .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #tjtoniyglh .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #tjtoniyglh .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #tjtoniyglh .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #tjtoniyglh .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #tjtoniyglh .gt_spanner_row { border-bottom-style: hidden; }
#  #tjtoniyglh .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #tjtoniyglh .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #tjtoniyglh .gt_from_md> :first-child { margin-top: 0; }
#  #tjtoniyglh .gt_from_md> :last-child { margin-bottom: 0; }
#  #tjtoniyglh .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #tjtoniyglh .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #tjtoniyglh .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #tjtoniyglh .gt_row_group_first td { border-top-width: 2px; }
#  #tjtoniyglh .gt_row_group_first th { border-top-width: 2px; }
#  #tjtoniyglh .gt_striped { background-color: #F4F4F4; }
#  #tjtoniyglh .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #tjtoniyglh .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #tjtoniyglh .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #tjtoniyglh .gt_left { text-align: left; }
#  #tjtoniyglh .gt_center { text-align: center; }
#  #tjtoniyglh .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #tjtoniyglh .gt_font_normal { font-weight: normal; }
#  #tjtoniyglh .gt_font_bold { font-weight: bold; }
#  #tjtoniyglh .gt_font_italic { font-style: italic; }
#  #tjtoniyglh .gt_super { font-size: 65%; }
#  #tjtoniyglh .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #tjtoniyglh .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:35%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 7: Any OGTT>11.1 ever</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_heading gt_co

# %%
# func for table 7
def get_table7_df(df_source: pd.DataFrame, visit_code: float) -> pd.DataFrame:
    df_month = df_source[(df_source.visit_code >= visit_code) & (df_source.visit_code <= visit_code + 0.9)].copy()

    row_df = df_month.copy()
    table_df = get_row_df(row_df, "Total (n)")

    row_df = df_month[(df_month.fbg_value < 6.1)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "FBG <6.1")])

    row_df = df_month[(df_month.fbg_value >= 6.1) & (df_month.fbg_value < 7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "FBG >=6.1 <7.0")])

    row_df = df_month[(df_month.fbg_value >= 7.0)].copy()
    table_df = pd.concat([table_df, get_row_df(row_df, "FBG >=7.0")])
    return table_df

# %%
# Table 8: Interim FBG results
df_table7 = get_table7_df(df_glucose, 1150.0)
df_table7 = format_table_df(df_table7, add_totals=False)
df_table7["visit_code"] = MONTH15

df_table71 = get_table7_df(df_glucose, 1180.0)
df_table71 = format_table_df(df_table71, add_totals=False)
df_table71["visit_code"] = MONTH18

df_table72 = get_table7_df(df_glucose, 1210.0)
df_table72 = format_table_df(df_table72, add_totals=False)
df_table72["visit_code"] = MONTH21

df_table73 = get_table7_df(df_glucose, 1270.0)
df_table73 = format_table_df(df_table73, add_totals=False)
df_table73["visit_code"] = MONTH27

df_table74 = get_table7_df(df_glucose, 1300.0)
df_table74 = format_table_df(df_table74, add_totals=False)
df_table74["visit_code"] = MONTH30

df_table75 = get_table7_df(df_glucose, 1330.0)
df_table75 = format_table_df(df_table75, add_totals=False)
df_table75["visit_code"] = MONTH33

df_table76 = get_table7_df(df_glucose, 1390.0)
df_table76 = format_table_df(df_table76, add_totals=False)
df_table76["visit_code"] = MONTH39

df_table = pd.concat([df_table7, df_table71, df_table72, df_table73, df_table74, df_table75, df_table76])
df_table = df_table.reset_index(drop=True)
df_table = df_table.fillna(0.0)

# %%
column_headers_with_str = {"visit_code": "Visit Code", **column_headers_with_str}
gt = df_as_great_table2(df_table, title="Table 8: Interim FBG results")
gt = (
    gt
    .cols_label(column_headers_with_str)
    .cols_move_to_start(columns="visit_code")
    .cols_align(align="center", columns=["10_str", "20_str", "30_str", "40_str", "60_str", "total_str"])
    .cols_align(align="left", columns=["visit_code", "label"])
    .cols_width(cases={"label": "15%"})
    .tab_style(
        style=[
            style.text(color="black", weight="bold"),
            style.fill(color="lightgray")
        ],
        locations=loc.row_groups()
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="ceajevlouf" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #ceajevlouf table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #ceajevlouf thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #ceajevlouf p { margin: 0; padding: 0; }
#  #ceajevlouf .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #ceajevlouf .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #ceajevlouf .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #ceajevlouf .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #ceajevlouf .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ceajevlouf .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ceajevlouf .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #ceajevlouf .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #ceajevlouf .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #ceajevlouf .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #ceajevlouf .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #ceajevlouf .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #ceajevlouf .gt_spanner_row { border-bottom-style: hidden; }
#  #ceajevlouf .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #ceajevlouf .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #ceajevlouf .gt_from_md> :first-child { margin-top: 0; }
#  #ceajevlouf .gt_from_md> :last-child { margin-bottom: 0; }
#  #ceajevlouf .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #ceajevlouf .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #ceajevlouf .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #ceajevlouf .gt_row_group_first td { border-top-width: 2px; }
#  #ceajevlouf .gt_row_group_first th { border-top-width: 2px; }
#  #ceajevlouf .gt_striped { background-color: #F4F4F4; }
#  #ceajevlouf .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #ceajevlouf .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #ceajevlouf .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #ceajevlouf .gt_left { text-align: left; }
#  #ceajevlouf .gt_center { text-align: center; }
#  #ceajevlouf .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #ceajevlouf .gt_font_normal { font-weight: normal; }
#  #ceajevlouf .gt_font_bold { font-weight: bold; }
#  #ceajevlouf .gt_font_italic { font-style: italic; }
#  #ceajevlouf .gt_super { font-size: 65%; }
#  #ceajevlouf .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #ceajevlouf .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:15%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 8: Interim FBG results</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id=""></th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10_str">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20_str">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30_str">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40_str">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60_str">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bot

# %%
# Table 9: Primary Endpoint met
df_endpoint_grp = df_endpoint.groupby(by=["site_id", "endpoint_label"]).size().to_frame().reset_index()
df_endpoint_grp.columns = ["site_id", "label", "endpoints"]
df_endpoint_pivot = df_endpoint_grp.pivot_table(index="label", columns="site_id", values="endpoints").reset_index()
df_endpoint_pivot.columns.name = ""
df_endpoint_pivot.columns = ['label', "10", "20", "30", "40", "60"]
df_endpoint_pivot.loc[len(df_endpoint_pivot)] = df_endpoint_pivot[['10', '20', '30', '40', '60']].sum().to_dict()
df_endpoint_pivot.at[len(df_endpoint_pivot) - 1, 'label'] = 'Total'
df_endpoint_pivot['total'] = df_endpoint_pivot[['10', '20', '30', '40', '60']].sum(axis=1)
df_endpoint_pivot = df_endpoint_pivot.fillna(0.0)

gt = df_as_great_table(
    df_endpoint_pivot,
    title="Table 9a: Primary Endpoint met"
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k not in ["visit_code"]})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "25%"})
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="swlxmftlgv" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #swlxmftlgv table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #swlxmftlgv thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #swlxmftlgv p { margin: 0; padding: 0; }
#  #swlxmftlgv .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #swlxmftlgv .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #swlxmftlgv .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #swlxmftlgv .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #swlxmftlgv .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #swlxmftlgv .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #swlxmftlgv .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #swlxmftlgv .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #swlxmftlgv .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #swlxmftlgv .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #swlxmftlgv .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #swlxmftlgv .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #swlxmftlgv .gt_spanner_row { border-bottom-style: hidden; }
#  #swlxmftlgv .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #swlxmftlgv .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #swlxmftlgv .gt_from_md> :first-child { margin-top: 0; }
#  #swlxmftlgv .gt_from_md> :last-child { margin-bottom: 0; }
#  #swlxmftlgv .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #swlxmftlgv .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #swlxmftlgv .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #swlxmftlgv .gt_row_group_first td { border-top-width: 2px; }
#  #swlxmftlgv .gt_row_group_first th { border-top-width: 2px; }
#  #swlxmftlgv .gt_striped { background-color: #F4F4F4; }
#  #swlxmftlgv .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #swlxmftlgv .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #swlxmftlgv .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #swlxmftlgv .gt_left { text-align: left; }
#  #swlxmftlgv .gt_center { text-align: center; }
#  #swlxmftlgv .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #swlxmftlgv .gt_font_normal { font-weight: normal; }
#  #swlxmftlgv .gt_font_bold { font-weight: bold; }
#  #swlxmftlgv .gt_font_italic { font-style: italic; }
#  #swlxmftlgv .gt_super { font-size: 65%; }
#  #swlxmftlgv .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #swlxmftlgv .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:25%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 9a: Primary Endpoint met</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_bord

# %%
df_endpoint.query("subject_identifier=='105-30-0225-7'")
# Out:
# Empty DataFrame
# Columns: [subject_identifier, site_id, baseline_datetime, visit_datetime, interval_in_days, visit_code, fbg_value, ogtt_value, fbg_datetime, fasted, endpoint_label, endpoint_type, endpoint, offstudy_datetime, offstudy_reason, test, days_to_endpoint]
# Index: []

# %%
from great_tables import html

# Table 9b: Primary Endpoint no EOS or DM Referral
df_subjecthistory = read_frame(
    SubjectScheduleHistory.objects.filter(offschedule_model="meta_prn.offschedule", offschedule_datetime__isnull=False),
    verbose=False).rename(columns={"site": "site_id"})
df_subjecthistory["site_id"] = df_subjecthistory["site_id"].astype(str)
df_endpoint_no_off = df_endpoint.merge(df_subjecthistory[["subject_identifier", "offschedule_datetime"]],
                                       on=["subject_identifier"], how="left")
df_endpoint_grp = df_endpoint_no_off.query("offschedule_datetime.isna()").groupby(
    by=["site_id", "endpoint_label"]).size().to_frame().reset_index()
df_endpoint_grp.columns = ["site_id", "label", "endpoints"]
df_endpoint_pivot = df_endpoint_grp.pivot_table(index="label", columns="site_id", values="endpoints").reset_index()
df_endpoint_pivot.columns.name = ""
df_endpoint_pivot.columns = ['label', *[str(col) for col in df_endpoint_pivot.columns if col != "label"]]
for col in [c for c in ['label', "10", "20", "30", "40", "60"] if str(c) not in df_endpoint_pivot.columns]:
    df_endpoint_pivot[str(col)] = np.nan
df_endpoint_pivot.columns = ['label', "10", "20", "30", "40", "60"]
df_endpoint_pivot.loc[len(df_endpoint_pivot)] = df_endpoint_pivot[['10', '20', '30', '40', '60']].sum().to_dict()
df_endpoint_pivot.at[len(df_endpoint_pivot) - 1, 'label'] = 'Total'
df_endpoint_pivot['total'] = df_endpoint_pivot[['10', '20', '30', '40', '60']].sum(axis=1)
df_endpoint_pivot = df_endpoint_pivot.fillna(0.0)
subjects = df_endpoint_no_off.query("offschedule_datetime.isna()").subject_identifier.to_list()

gt = df_as_great_table(
    df_endpoint_pivot,
    title="Table 9b: Primary Endpoint met -- participant not referred"
)
gt = (
    gt
    .cols_label({k: v for k, v in column_headers.items() if k not in ["visit_code"]})
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .cols_align(align="left", columns=["label"])
    .cols_width(cases={"label": "25%"})
    .tab_source_note(source_note=html("<BR>".join(subjects)))
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="lslndenyrz" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #lslndenyrz table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #lslndenyrz thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #lslndenyrz p { margin: 0; padding: 0; }
#  #lslndenyrz .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #lslndenyrz .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #lslndenyrz .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #lslndenyrz .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #lslndenyrz .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #lslndenyrz .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #lslndenyrz .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #lslndenyrz .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #lslndenyrz .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #lslndenyrz .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #lslndenyrz .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #lslndenyrz .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #lslndenyrz .gt_spanner_row { border-bottom-style: hidden; }
#  #lslndenyrz .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #lslndenyrz .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #lslndenyrz .gt_from_md> :first-child { margin-top: 0; }
#  #lslndenyrz .gt_from_md> :last-child { margin-bottom: 0; }
#  #lslndenyrz .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #lslndenyrz .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #lslndenyrz .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #lslndenyrz .gt_row_group_first td { border-top-width: 2px; }
#  #lslndenyrz .gt_row_group_first th { border-top-width: 2px; }
#  #lslndenyrz .gt_striped { background-color: #F4F4F4; }
#  #lslndenyrz .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #lslndenyrz .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #lslndenyrz .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #lslndenyrz .gt_left { text-align: left; }
#  #lslndenyrz .gt_center { text-align: center; }
#  #lslndenyrz .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #lslndenyrz .gt_font_normal { font-weight: normal; }
#  #lslndenyrz .gt_font_bold { font-weight: bold; }
#  #lslndenyrz .gt_font_italic { font-style: italic; }
#  #lslndenyrz .gt_super { font-size: 65%; }
#  #lslndenyrz .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #lslndenyrz .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table style="table-layout: fixed;; width: 100%" class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <colgroup>
#   <col style="width:25%;"/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
# </colgroup>
#
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 9b: Primary Endpoint met -- participant not referred</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_he

# %%
# export subject_identifiers who reached endpoint
# df_endpoint_no_off[["subject_identifier", "endpoint_label"]].to_stata(analysis_folder / "endpoints_20250906.dta")

# %%
# Table 10: Incident Rate per 1000 person-years

def get_df_main(df_visit: pd.DataFrame, lower_days: float | None = None, upper_days: float | None = None):
    if not lower_days:
        lower_days = -1
    # cutoff_datetime = df_visit.query("@lower_days<followup_days<=@upper_days").visit_datetime.max()
    # exclude subjects for this reason
    offstudy_reasons = [
        'Patient fulfilled late exclusion criteria (due to abnormal blood values or raised blood pressure at enrolment']

    df_eos = get_eos_df()
    df_eos_excluded = (
        df_eos
        .query("followup_days>@lower_days and followup_days<=@upper_days and offstudy_reason.isin(@offstudy_reasons)")
        .copy()
        .reset_index()
    )
    df_visit_final = (
        df_visit.query("@lower_days<followup_days<=@upper_days and reason!='missed' and visit_code<2000.0")
        .merge(df_eos_excluded[["subject_identifier"]], on="subject_identifier", how="left", suffixes=("", "_y"),
               indicator=True)
        .query("_merge=='left_only'")
        .drop(columns=["_merge"])
    )
    df_main = (
        df_visit_final
        .groupby(by=["subject_identifier"])[["baseline_datetime", "visit_datetime", "followup_days"]]
        .max()
        .reset_index()
    )

    df_main = (
        df_main
        .merge(
            df_endpoint.query("days_to_endpoint>@lower_days")[
                ["subject_identifier", "endpoint_label", "endpoint_type", "days_to_endpoint"]],
            how="left",
            on=["subject_identifier"])
        .reset_index(drop=True)
    )
    if lower_days >= 365.25:
        df_main["followup_days"] = df_main["followup_days"] - lower_days
    df_main["followup_years"] = df_main["followup_days"] / 365.25
    return df_main, len(df_main), len(
        df_main.query("@lower_days<days_to_endpoint<=@upper_days and endpoint_label.notna()"))


def get_rate_and_ci(events, person_years_total):
    lower_ci = (chi2.ppf(0.025, 2 * events) / (2 * person_years_total)) * 1000
    upper_ci = (chi2.ppf(0.975, 2 * (events + 1)) / (2 * person_years_total)) * 1000
    return events / person_years_total * 1000, lower_ci, upper_ci


def get_incidence_data(term: str, lower_days: float, upper_days: float):
    data = {}
    df_main, subjects, events = get_df_main(df_visit, lower_days=lower_days, upper_days=upper_days)
    person_years_total = df_main.followup_years.sum()
    data.update({term: [person_years_total, subjects, events, *get_rate_and_ci(events, person_years_total)]})
    return data

# %%
incidence_data = {}
incidence_data.update(get_incidence_data("total", lower_days=-1, upper_days=10000))
incidence_data.update(get_incidence_data("0-1 years", lower_days=-1, upper_days=365.25))
incidence_data.update(get_incidence_data("1-2 years", lower_days=365.25, upper_days=2 * 365.25))
incidence_data.update(get_incidence_data("2-3 years", lower_days=2 * 365.25, upper_days=3 * 365.25))
incidence_data.update(get_incidence_data("3+ years", lower_days=3 * 365.25, upper_days=10 * 365.25))
data = dict(label=[], person_years=[], subjects=[], failures=[], rate=[], lower_ci=[], upper_ci=[])
for k in incidence_data:
    data["label"].append(k)

for v in incidence_data.values():
    data["person_years"].append(v[0])
    data["subjects"].append(v[1])
    data["failures"].append(v[2])
    data["rate"].append(v[3])
    data["lower_ci"].append(v[4])
    data["upper_ci"].append(v[5])

df_table9 = pd.DataFrame(data={k: v for k, v in data.items() if k != "subjects"})

# %%
gt = df_as_great_table(
    df_table9,
    title="Table 10: Incident Rate per 1000 person years",
    subtitle=md("using randomisation to diabetes/last seen"),
)
gt = gt.fmt_number(columns=["person_years", "failures", "rate", "lower_ci", "upper_ci"], decimals=2)
gt = (gt
      .cols_label(
    {"label": "Label", "person_years": "Person years", "failures": "Failures", "rate": "Rate", "lower_ci": "Lower",
     "upper_ci": "Upper"})
      .cols_align(align="left", columns=["label"])
      .cols_align(align="center", columns=["person_years", "failures", "rate", "lower_ci", "upper_ci"])
      .tab_spanner(
    label="95%CI",
    columns=["lower_ci", "upper_ci"],
)
      .tab_source_note(source_note="Excluding patients withdrawn for `late exclusion` criteria")
      )
gt.show()
html_data.append(gt.as_raw_html())
# Out:
# <div id="rhkzxypxwg" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #rhkzxypxwg table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #rhkzxypxwg thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #rhkzxypxwg p { margin: 0; padding: 0; }
#  #rhkzxypxwg .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #rhkzxypxwg .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #rhkzxypxwg .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #rhkzxypxwg .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #rhkzxypxwg .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rhkzxypxwg .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #rhkzxypxwg .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #rhkzxypxwg .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #rhkzxypxwg .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #rhkzxypxwg .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #rhkzxypxwg .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #rhkzxypxwg .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #rhkzxypxwg .gt_spanner_row { border-bottom-style: hidden; }
#  #rhkzxypxwg .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #rhkzxypxwg .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #rhkzxypxwg .gt_from_md> :first-child { margin-top: 0; }
#  #rhkzxypxwg .gt_from_md> :last-child { margin-bottom: 0; }
#  #rhkzxypxwg .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #rhkzxypxwg .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #rhkzxypxwg .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #rhkzxypxwg .gt_row_group_first td { border-top-width: 2px; }
#  #rhkzxypxwg .gt_row_group_first th { border-top-width: 2px; }
#  #rhkzxypxwg .gt_striped { background-color: #F4F4F4; }
#  #rhkzxypxwg .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #rhkzxypxwg .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #rhkzxypxwg .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #rhkzxypxwg .gt_left { text-align: left; }
#  #rhkzxypxwg .gt_center { text-align: center; }
#  #rhkzxypxwg .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #rhkzxypxwg .gt_font_normal { font-weight: normal; }
#  #rhkzxypxwg .gt_font_bold { font-weight: bold; }
#  #rhkzxypxwg .gt_font_italic { font-style: italic; }
#  #rhkzxypxwg .gt_super { font-size: 65%; }
#  #rhkzxypxwg .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #rhkzxypxwg .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 10: Incident Rate per 1000 person years</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="6" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">using randomisation to diabetes/last seen</td>
#   </tr>
# <tr class="gt_col_headings gt_spanner_row">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="2" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="person_years">Person years</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="failures">Failures</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="rate">Rate</th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="95%CI">
#     <span class="gt_column_spanner">95%CI</span>
#   </th>
# </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_

# %%
# Table 11: Proportion meeting primary endpoint
df_table10 = pd.DataFrame(data=data)
df_table10["proportion"] = df_table10["failures"] / df_table10["subjects"] * 100
gt = df_as_great_table(
    df_table10[["label", "subjects", 'failures', "proportion"]],
    title="Table 11: Proportion meeting primary endpoint",
)
gt = (
    gt
    .fmt_number(columns=["failures", "proportion"], decimals=2)
    .cols_label({"label": "Label", "subjects": "Participants", "failures": "Failures", "proportion": "%"})
    .cols_align(align="left", columns=["label"])
    .cols_align(align="center", columns=["subjects", "failures", "proportion"])
    .tab_source_note(source_note="Excluding patients withdrawn for `late exclusion` criteria")
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="aksazcxjwf" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #aksazcxjwf table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #aksazcxjwf thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #aksazcxjwf p { margin: 0; padding: 0; }
#  #aksazcxjwf .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #aksazcxjwf .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #aksazcxjwf .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #aksazcxjwf .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #aksazcxjwf .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #aksazcxjwf .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #aksazcxjwf .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #aksazcxjwf .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #aksazcxjwf .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #aksazcxjwf .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #aksazcxjwf .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #aksazcxjwf .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #aksazcxjwf .gt_spanner_row { border-bottom-style: hidden; }
#  #aksazcxjwf .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #aksazcxjwf .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #aksazcxjwf .gt_from_md> :first-child { margin-top: 0; }
#  #aksazcxjwf .gt_from_md> :last-child { margin-bottom: 0; }
#  #aksazcxjwf .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #aksazcxjwf .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #aksazcxjwf .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #aksazcxjwf .gt_row_group_first td { border-top-width: 2px; }
#  #aksazcxjwf .gt_row_group_first th { border-top-width: 2px; }
#  #aksazcxjwf .gt_striped { background-color: #F4F4F4; }
#  #aksazcxjwf .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #aksazcxjwf .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #aksazcxjwf .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #aksazcxjwf .gt_left { text-align: left; }
#  #aksazcxjwf .gt_center { text-align: center; }
#  #aksazcxjwf .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #aksazcxjwf .gt_font_normal { font-weight: normal; }
#  #aksazcxjwf .gt_font_bold { font-weight: bold; }
#  #aksazcxjwf .gt_font_italic { font-style: italic; }
#  #aksazcxjwf .gt_super { font-size: 65%; }
#  #aksazcxjwf .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #aksazcxjwf .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="4" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 11: Proportion meeting primary endpoint</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="label">Label</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="subjects">Participants</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="failures">Failures</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="proportion">%</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr>
#     <td style="background-color: snow; color: black; background-color: lightgray; color: black;" class="gt_row gt_left">total</td>
#     <td style="background-color: snow; color: black;" class="gt_row gt_center">1630</td>
#     <td style="background-color: snow; color: black;" class="gt_row gt_center">85.00</td>
#     <td style="background-color: snow; color: black;"

# %%
# Table 11a: End of Study Table (for those who have completed an end of study form)
df_eos = get_eos_df()
offstudy_reasons = {
    "Delivered / Completed followup from pregnancy": "Pregnancy",
    "Patient completed 36 months of follow-up": "Completed 36m",
    "Patient developed diabetes": "Developed diabetes",
    "Other reason (specify below)": "Other",
    "Patient fulfilled late exclusion criteria (due to abnormal blood values or raised blood pressure at enrolment": "Late exclusion",
    "Patient has been transferred to another health centre": "Transferred out",
    "Patient is withdrawn on CLINICAL grounds ...": "Withdrawal: Clinical grounds",
    "Patient lost to follow-up": "LTFU",
    "Patient reported/known to have died": "Died",
    "Patient withdrew consent to participate further": "Withdrawal: Consent",
}
df_eos["offstudy_reason"] = df_eos["offstudy_reason"].map(offstudy_reasons)
df_eos["offstudy_reason"] = pd.Categorical(df_eos["offstudy_reason"],
                                           categories=sorted(list(offstudy_reasons.values())), ordered=True)
df_eos["site_id"] = df_eos["site_id"].astype(str)
df_eos_pivot = (
    df_eos
    .groupby(by=["offstudy_reason", "site_id"], observed=True)
    .size()
    .reset_index()
    .pivot_table(index="offstudy_reason", columns="site_id", values=0, observed=True)
    .fillna(0)
    .astype(int)
    .reset_index()
)
df_eos_pivot["total"] = df_eos_pivot[["10", "20", "30", "40", "60"]].sum(axis=1)
df_eos_pivot.columns.name = ""
sum_row = df_eos_pivot.select_dtypes(include='int64').sum()
sum_row['offstudy_reason'] = 'Total'
sum_row_df = pd.DataFrame(sum_row).T
enrolled_1691_pivot["offstudy_reason"] = "Enrolled"
enrolled_1691_pivot = enrolled_1691_pivot[[*df_eos_pivot.columns]]
df_eos_pivot = pd.concat([enrolled_1691_pivot, df_eos_pivot, sum_row_df], ignore_index=True)

gt = df_as_great_table(
    df_eos_pivot,
    title="Table 12a: End of study report",
    subtitle=md("for those who have completed an End of study report"),
)
gt = (
    gt
    .cols_label(
        {"offstudy_reason": "Reason", **{k: v for k, v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="left", columns=["offstudy_reason"])
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=[len(df_eos_pivot) - 1]),
    )
    .tab_style(
        style=[style.fill(color="lightblue"), style.text(color="black")],
        locations=loc.body(
            columns=["10", "20", "30", "40", "60"],
            rows=[len(df_eos_pivot) - 1],
        ),
    )
    .tab_style(
        style=[style.fill(color="lightgreen"), style.text(color="black")],
        locations=loc.body(
            columns=["total"],
            rows=[len(df_eos_pivot) - 1],
        ),
    )
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=["offstudy_reason"],
            rows=[0],
        ),
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="kuwesnbzor" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #kuwesnbzor table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #kuwesnbzor thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #kuwesnbzor p { margin: 0; padding: 0; }
#  #kuwesnbzor .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #kuwesnbzor .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #kuwesnbzor .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #kuwesnbzor .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #kuwesnbzor .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #kuwesnbzor .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #kuwesnbzor .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #kuwesnbzor .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #kuwesnbzor .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #kuwesnbzor .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #kuwesnbzor .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #kuwesnbzor .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #kuwesnbzor .gt_spanner_row { border-bottom-style: hidden; }
#  #kuwesnbzor .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #kuwesnbzor .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #kuwesnbzor .gt_from_md> :first-child { margin-top: 0; }
#  #kuwesnbzor .gt_from_md> :last-child { margin-bottom: 0; }
#  #kuwesnbzor .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #kuwesnbzor .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #kuwesnbzor .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #kuwesnbzor .gt_row_group_first td { border-top-width: 2px; }
#  #kuwesnbzor .gt_row_group_first th { border-top-width: 2px; }
#  #kuwesnbzor .gt_striped { background-color: #F4F4F4; }
#  #kuwesnbzor .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #kuwesnbzor .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #kuwesnbzor .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #kuwesnbzor .gt_left { text-align: left; }
#  #kuwesnbzor .gt_center { text-align: center; }
#  #kuwesnbzor .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #kuwesnbzor .gt_font_normal { font-weight: normal; }
#  #kuwesnbzor .gt_font_bold { font-weight: bold; }
#  #kuwesnbzor .gt_font_italic { font-style: italic; }
#  #kuwesnbzor .gt_super { font-size: 65%; }
#  #kuwesnbzor .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #kuwesnbzor .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 12a: End of study report</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">for those who have completed an End of study report</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="offstudy_reason">Reason</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="

# %%
# Table 12b: Study status
def get_schedule_df(df_subjecthistory: pd.DataFrame, onschedule_model: str, offschedule_model: str,
                    mode: str) -> pd.DataFrame:
    columns = {k: f"{k}_{mode}" for k in ["10", "20", "30", "40", "60"]}
    df_schedule = (
        df_subjecthistory
        .query(
            f"onschedule_model==@onschedule_model and offschedule_model==@offschedule_model and offschedule_datetime.{'isna' if mode == 'on' else 'notna'}()")
        .groupby(by=["onschedule_model", "site_id"])
        .size()
        .reset_index()
        .pivot_table(index="onschedule_model", columns="site_id", values=0, observed=True)
        .reset_index()
        .rename(columns={"onschedule_model": "schedule", **columns})
        .fillna(0)
        .copy()
    )
    df_schedule.columns.name = ""
    return df_schedule


df_subjecthistory = read_frame(SubjectScheduleHistory.objects.all(), verbose=False).rename(columns={"site": "site_id"})
df_subjecthistory["site_id"] = df_subjecthistory["site_id"].astype(str)

df_on = pd.concat([
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedule', 'meta_prn.offschedule', "on"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onscheduledmreferral', 'meta_prn.offscheduledmreferral', "on"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedulepregnancy', 'meta_prn.offschedulepregnancy', "on"),
])

df_on = (
    df_on
    .fillna(0)
    .reset_index(drop=True)
)

df_off = pd.concat([
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedule', 'meta_prn.offschedule', "off"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onscheduledmreferral', 'meta_prn.offscheduledmreferral', "off"),
    get_schedule_df(df_subjecthistory, 'meta_prn.onschedulepregnancy', 'meta_prn.offschedulepregnancy', "off"),
])
df_off = (
    df_off
    .fillna(0)
    .reset_index(drop=True)
)

df_status = pd.merge(df_on, df_off, on=["schedule"], how="outer")
columns = []
for ele in [[f"{x}_on", f"{x}_off"] for x in ["10", "20", "30", "40", "60"]]:
    columns.extend(ele)
df_status = df_status[["schedule", *columns]]
df_status["total_on"] = df_status[[col for col in columns if "on" in col]].sum(axis=1)
df_status["total_off"] = df_status[[col for col in columns if "off" in col]].sum(axis=1)
df_status["total"] = df_status[columns].sum(axis=1)
df_status["schedule"] = df_status.schedule.map(
    {"meta_prn.onschedule": "Main trial", "meta_prn.onscheduledmreferral": "Diabetes",
     "meta_prn.onschedulepregnancy": "Pregnancy"})

gt = df_as_great_table(
    df_status,
    title="Table 12b: Study status",
    subtitle=md("Calculated from Offschedule form; not End of study report"),
)
# gt = gt.fmt_number(columns=["person_years", "failures", "rate", "lower_ci", "upper_ci"], decimals=0)
gt = (gt
      .tab_source_note(
    source_note=(
        "Note: Offschedule form is always submitted before the End of study report. "
        "When the Offschedule form is submitted, future appointments for the schedule are removed and "
        "the site staff are actioned to submit the End of study report."
    )
)
      .cols_label({
    "10_on": "On", "10_off": "Off",
    "20_on": "On", "20_off": "Off",
    "30_on": "On", "30_off": "Off",
    "40_on": "On", "40_off": "Off",
    "60_on": "On", "60_off": "Off",
    "total_on": "On", "total_off": "Off",
    "schedule": "Schedule", "total": "Total"})
      .cols_align(align="center")
      .cols_align(align="left", columns=["label"])
      .tab_spanner(
    label="Hindu mandal",
    columns=["10_on", "10_off"],
)
      .tab_spanner(
    label="Amana",
    columns=["20_on", "20_off"],
)
      .tab_spanner(
    label="Temeke",
    columns=["30_on", "30_off"],
)
      .tab_spanner(
    label="Mwananyamala",
    columns=["40_on", "40_off"],
)
      .tab_spanner(
    label="Mnazi Moja",
    columns=["60_on", "60_off"],
)
      .tab_spanner(
    label="Total",
    columns=["total_on", "total_off"],
)
      .tab_style(
    style=[style.fill(color="lightblue"), style.text(color="black")],
    locations=loc.body(
        columns=["10_off", "20_off", "30_off", "40_off", "60_off"],
        rows=list(range(0, 1)),
    ),
)
      .tab_style(
    style=[style.fill(color="lightgreen"), style.text(color="black")],
    locations=loc.body(
        columns=["total_off"],
        rows=list(range(0, 1)),
    ),
)
      .fmt_number(columns=[*[c for c in df_status.columns if c not in ["schedule"]]], decimals=0)
      )
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="shmsijzjbz" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #shmsijzjbz table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #shmsijzjbz thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #shmsijzjbz p { margin: 0; padding: 0; }
#  #shmsijzjbz .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #shmsijzjbz .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #shmsijzjbz .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #shmsijzjbz .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #shmsijzjbz .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #shmsijzjbz .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #shmsijzjbz .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #shmsijzjbz .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #shmsijzjbz .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #shmsijzjbz .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #shmsijzjbz .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #shmsijzjbz .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #shmsijzjbz .gt_spanner_row { border-bottom-style: hidden; }
#  #shmsijzjbz .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #shmsijzjbz .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #shmsijzjbz .gt_from_md> :first-child { margin-top: 0; }
#  #shmsijzjbz .gt_from_md> :last-child { margin-bottom: 0; }
#  #shmsijzjbz .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #shmsijzjbz .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #shmsijzjbz .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #shmsijzjbz .gt_row_group_first td { border-top-width: 2px; }
#  #shmsijzjbz .gt_row_group_first th { border-top-width: 2px; }
#  #shmsijzjbz .gt_striped { background-color: #F4F4F4; }
#  #shmsijzjbz .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #shmsijzjbz .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #shmsijzjbz .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #shmsijzjbz .gt_left { text-align: left; }
#  #shmsijzjbz .gt_center { text-align: center; }
#  #shmsijzjbz .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #shmsijzjbz .gt_font_normal { font-weight: normal; }
#  #shmsijzjbz .gt_font_bold { font-weight: bold; }
#  #shmsijzjbz .gt_font_italic { font-style: italic; }
#  #shmsijzjbz .gt_super { font-size: 65%; }
#  #shmsijzjbz .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #shmsijzjbz .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="14" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 12b: Study status</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="14" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">Calculated from Offschedule form; not End of study report</td>
#   </tr>
# <tr class="gt_col_headings gt_spanner_row">
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="2" colspan="1" scope="col" id="schedule">Schedule</th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="Hindu-mandal">
#     <span class="gt_column_spanner">Hindu mandal</span>
#   </th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="Amana">
#     <span class="gt_column_spanner">Amana</span>
#   </th>
#   <th class="gt_center gt_columns_top_border gt_column_spanner_outer" rowspan="1" colspan="2" scope="colgroup" id="Temeke">
#     <span class="gt_column_spanner">Temeke</span>
#   </th>
#   <th class="gt_center gt_columns_top_border gt_column_span

# %%
# off schedule no eos

subjects_preg_dm = df_subjecthistory[~(df_subjecthistory.offschedule_datetime.isna()) & (
        df_subjecthistory.schedule_name != "schedule")].subject_identifier

df_subjecthistory[
    ~(df_subjecthistory.subject_identifier.isin(df_eos_1691.subject_identifier))].sort_values(
    by=["subject_identifier", "onschedule_datetime"])
# Out:
#                                                revision  \
# 1665  0.1.61-233-g493c02f:develop:493c02fa1931cfe26b...
# 1378  0.1.61-233-g493c02f:develop:493c02fa1931cfe26b...
# 1562  0.1.61-233-g493c02f:develop:493c02fa1931cfe26b...
# 459   0.1.61-233-g493c02f:develop:493c02fa1931cfe26b...
# 1064  0.1.61-233-g493c02f:develop:493c02fa1931cfe26b...
# ...                                                 ...
# 1371  0.2.41:main:fec3ea86c27d8bcdb2047bdba4665843dd...
# 566   0.2.41:main:fec3ea86c27d8bcdb2047bdba4665843dd...
# 1613  0.2.41:main:fec3ea86c27d8bcdb2047bdba4665843dd...
# 1535  0.2.41:main:fec3ea86c27d8bcdb2047bdba4665843dd...
# 736   0.2.41:main:fec3ea86c27d8bcdb2047bdba4665843dd...
#
#                               created                         modified  \
# 1665 2021-11-16 09:19:59.916145+00:00 2021-11-16 09:19:59.916145+00:00
# 1378 2021-11-30 09:05:58.150673+00:00 2021-11-30 09:05:58.150673+00:00
# 1562 2021-12-02 09:18:45.001285+00:00 2021-12-02 09:18:45.001285+00:00
# 459  2021-12-03 08:16:42.984813+00:00 2021-12-03 08:16:42.984813+00:00
# 1064 2021-12-06 10:10:12.319320+00:00 2021-12-06 10:10:12.319320+00:00
# ...                               ...                              ...
# 1371 2023-11-29 08:19:21.460863+00:00 2023-11-29 08:19:21.460863+00:00
# 566  2023-11-30 08:29:53.589314+00:00 2023-11-30 08:29:53.589314+00:00
# 1613 2023-12-21 08:48:26.036598+00:00 2023-12-21 08:48:26.036598+00:00
# 1535 2023-12-28 09:01:03.816240+00:00 2023-12-28 09:01:03.816240+00:00
# 736  2024-01-03 05:55:07.094789+00:00 2024-01-03 05:55:07.094789+00:00
#
#      user_created user_modified hostname_created hostname_modified  \
# 1665                                       meta3             meta3
# 1378                                       meta3             meta3
# 1562                                       meta3             meta3
# 459                                        meta3             meta3
# 1064                                       meta3             meta3
# ...           ...           ...              ...               ...
# 1371                                       meta3             meta3
# 566                                        meta3             meta3
# 1613                                       meta3             meta3
# 1535                                       meta3             meta3
# 736                                        meta3             meta3
#
#      device_created device_modified locale_created  ...  \
# 1665             99              99           None  ...
# 1378             99              99           None  ...
# 1562             99              99           None  ...
# 459              99              99           None  ...
# 1064             99              99           None  ...
# ...             ...             ...            ...  ...
# 1371             99              99           None  ...
# 566              99              99           None  ...
# 1613             99              99           None  ...
# 1535             99              99           None  ...
# 736              99              99           None  ...
#
#                                         id subject_identifier site_id  \
# 1665  f2137437-19c6-458c-b115-f4bfc14f347c      105-10-0001-4      10
# 1378  cba2dd82-7354-41cc-9c69-e4ca7ae223aa      105-10-0004-8      10
# 1562  e3088404-6b95-4165-b3e2-3acf5ad35775      105-10-0005-5      10
# 459   43d5e0ef-2cc9-4a9f-bf1e-ae8e493f87da      105-10-0007-1      10
# 1064  a12bbbfa-92c0-4b0b-87d5-88f8b0d58d21      105-10-0008-9      10
# ...                                    ...                ...     ...
# 1371  cac75984-04fc-4500-9594-d0e0b06af953      105-60-0226-2      60
# 566   527719d6-15d7-4218-b7fc-8b8802d4e0f2      105-60-0227-0      60
# 1613  eac04e0e-7286-460f-b4f6-cf0e00904e1e      105-60-0228-8      60
# 1535  df7c06e5-26d0-4f1e-aae6-47ce81a5302c      105-60-0229-6      60
# 736   6a728280-f616-417c-ad3b-8b3d1918b909      105-60-0230-4      60
#
#      visit_schedule_name schedule_name     onschedule_model  \
# 1665      visit_schedule      schedule  meta_prn.onschedule
# 1378      visit_schedule      schedule  meta_prn.onschedule
# 1562      visit_schedule      schedule  meta_prn.onschedule
# 459       visit_schedule      schedule  meta_prn.onschedule
# 1064      visit_schedule      schedule  meta_prn.onschedule
# ...                  ...           ...                  ...
# 1371      visit_schedule      schedule  meta_prn.onschedule
# 566       visit_schedule      schedule  meta_prn.onschedule
# 1613      visit_schedule      schedule  meta_prn.onschedule
# 1535      visit_schedule      schedule  meta_prn.onschedule
# 736       visit_schedule      schedule  meta_prn.onschedule
#
#          offschedule_model       onschedule_datetime offschedule_datetime  \
# 1665  meta_prn.offschedule 2021-11-16 09:19:07+00:00                  NaT
# 1378  meta_prn.offschedule 2021-11-30 09:02:08+00:00                  NaT
# 1562  meta_prn.offschedule 2021-12-02 09:16:19+00:00                  NaT
# 459   meta_prn.offschedule 2021-12-03 08:08:44+00:00                  NaT
# 1064  meta_prn.offschedule 2021-12-06 10:08:43+00:00                  NaT
# ...                    ...                       ...                  ...
# 1371  meta_prn.offschedule 2023-11-29 08:17:23+00:00                  NaT
# 566   meta_prn.offschedule 2023-11-30 08:26:43+00:00                  NaT
# 1613  meta_prn.offschedule 2023-12-21 08:45:47+00:00                  NaT
# 1535  meta_prn.offschedule 2023-12-28 08:58:26+00:00                  NaT
# 736   meta_prn.offschedule 2024-01-03 05:52:38+00:00                  NaT
#
#      schedule_status
# 1665      onschedule
# 1378      onschedule
# 1562      onschedule
# 459       onschedule
# 1064      onschedule
# ...              ...
# 1371      onschedule
# 566       onschedule
# 1613      onschedule
# 1535      onschedule
# 736       onschedule
#
# [1507 rows x 21 columns]

# %%
# Table 13: Loss to Follow Up
df_ltfu = read_frame(LossToFollowup.objects.all(), verbose=False).rename(columns={"site": "site_id"})
df_ltfu_pivot = (
    df_ltfu
    .groupby(by=["loss_category", "site_id"], observed=True, dropna=False)
    .size()
    .reset_index()
    .pivot_table(index="loss_category", columns="site_id", values=0, observed=True, dropna=False)
    .fillna(0)
    .astype(int)
    .reset_index()
)
df_ltfu_pivot["total"] = df_eos_pivot[["10", "20", "30", "40", "60"]].sum(axis=1)
df_ltfu_pivot.columns.name = ""
sum_row = df_ltfu_pivot.select_dtypes(include='int64').sum()
sum_row['loss_category'] = 'Total'
sum_row_df = pd.DataFrame(sum_row).T
df_ltfu_pivot = pd.concat([df_ltfu_pivot, sum_row_df], ignore_index=True)
df_ltfu_pivot
# Out:
#   loss_category 60   total
# 0         OTHER  1  1691.0
# 1         Total  1     NaN

# %%
# Table 13c: End of study report not submitted

df1 = (
    df_status
    .query("schedule=='Main trial'")[[col for col in columns if "off" in col]]
    .rename(columns=dict(zip([col for col in columns if "off" in col], ["10", "20", "30", "40", "60"], strict=False)))
    .reset_index(drop=True)
)
df2 = (
    df_eos_pivot
    .query("offstudy_reason=='Total'")[["10", "20", "30", "40", "60"]]
    .reset_index(drop=True)
)

df_eos_not_reported = df1 - df2
df_eos_not_reported["schedule"] = 'Main trial'
df_eos_not_reported["total"] = df_eos_not_reported[["10", "20", "30", "40", "60"]].sum(axis=1)
df_eos_not_reported = df_eos_not_reported[["schedule", "10", "20", "30", "40", "60", "total"]]

gt = df_as_great_table(
    df_eos_not_reported,
    title="Table 13c: End of study report not submitted",
    subtitle=md("End of study report expected based on Offschedule form"),
)
gt = (
    gt
    .cols_label(
        {"schedule": "Schedule", **{k: v for k, v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="left", columns=["schedule"])
    .cols_align(align="center", columns=["10", "20", "30", "40", "60", "total"])
    .tab_style(
        style=[style.fill(color="snow"), style.text(color="black")],
        locations=loc.body(
            columns=[0],
            rows=[len(df_eos_pivot) - 1]),
    )
    .tab_style(
        style=[style.fill(color="lightblue"), style.text(color="black")],
        locations=loc.body(
            columns=["10", "20", "30", "40", "60"],
            rows=[len(df_eos_pivot) - 1],
        ),
    )
    .tab_style(
        style=[style.fill(color="lightgreen"), style.text(color="black")],
        locations=loc.body(
            columns=["total"],
            rows=[len(df_eos_pivot) - 1],
        ),
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="wirktbupcm" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #wirktbupcm table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #wirktbupcm thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #wirktbupcm p { margin: 0; padding: 0; }
#  #wirktbupcm .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #wirktbupcm .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #wirktbupcm .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #wirktbupcm .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #wirktbupcm .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wirktbupcm .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #wirktbupcm .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #wirktbupcm .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #wirktbupcm .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #wirktbupcm .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #wirktbupcm .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #wirktbupcm .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #wirktbupcm .gt_spanner_row { border-bottom-style: hidden; }
#  #wirktbupcm .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #wirktbupcm .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #wirktbupcm .gt_from_md> :first-child { margin-top: 0; }
#  #wirktbupcm .gt_from_md> :last-child { margin-bottom: 0; }
#  #wirktbupcm .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #wirktbupcm .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #wirktbupcm .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #wirktbupcm .gt_row_group_first td { border-top-width: 2px; }
#  #wirktbupcm .gt_row_group_first th { border-top-width: 2px; }
#  #wirktbupcm .gt_striped { background-color: #F4F4F4; }
#  #wirktbupcm .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #wirktbupcm .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #wirktbupcm .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #wirktbupcm .gt_left { text-align: left; }
#  #wirktbupcm .gt_center { text-align: center; }
#  #wirktbupcm .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #wirktbupcm .gt_font_normal { font-weight: normal; }
#  #wirktbupcm .gt_font_bold { font-weight: bold; }
#  #wirktbupcm .gt_font_italic { font-style: italic; }
#  #wirktbupcm .gt_super { font-size: 65%; }
#  #wirktbupcm .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #wirktbupcm .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 13c: End of study report not submitted</div></td>
#   </tr>
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_subtitle gt_font_normal gt_bottom_border">End of study report expected based on Offschedule form</td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="schedule">Schedule</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>

# %%
# Table 14: Baseline Sample

# %%
# Table 15: Consented to extended followup
df_consented = (
    read_frame(SubjectConsentV1Ext.objects.all(), verbose=False)
    .query("agrees_to_extension==@YES")
    .rename(columns={"site": "site_id"})
)
df_consented["site_id"] = df_consented.site_id.astype(str)
df_consented["month"] = df_consented.report_datetime.dt.strftime("%m")
df_consented["year"] = df_consented.report_datetime.dt.strftime("%Y")
df_consented_grp = (
    df_consented.groupby(by=["site_id", "year", "month"]).
    size()
    .reset_index()
    .sort_values(by=["site_id", "year", "month"], ascending=True)
    .reset_index(drop=True)
)
df_consented_pivot = (
    df_consented_grp
    .pivot_table(index=["year", "month"], columns="site_id", values=0, aggfunc="sum")
    .reset_index()
    .fillna(0)
)
if "60" not in df_consented_pivot.columns:
    df_consented_pivot["60"] = 0.0 * len(df_consented_pivot)
df_consented_pivot.columns.name = ""
df_consented_pivot["year"] = df_consented_pivot["year"].astype(str)
df_consented_pivot["month"] = df_consented_pivot["month"].astype(str)

sum_row = df_consented_pivot[["10", "20", "30", "40", "60"]].sum()
sum_row['year'] = "Total"
sum_row['month'] = ""
df_consented_pivot = pd.concat([df_consented_pivot, sum_row.to_frame().T], ignore_index=True)
df_consented_pivot["total"] = df_consented_pivot[["10", "20", "30", "40", "60"]].sum(axis=1).astype(int)
df_consented_pivot[["10", "20", "30", "40", "60"]] = df_consented_pivot[["10", "20", "30", "40", "60"]].astype(int)
gt = df_as_great_table2(
    df_consented_pivot,
    title="Table 15: Consented to extended followup",
    rowname_col="month",
    groupname_col="year",
)
gt = (
    gt
    .cols_label({"year": "Year", "month": "Month",
                 **{k: v for k, v in column_headers.items() if k not in ["visit_code", "label"]}})
    .cols_align(align="center")
    .fmt_number(columns=["10", "20", "30", "40", "60", "total"], decimals=0)
    .tab_stubhead(label="Consented")
    .tab_style(
        style=[
            style.text(color="black", weight="bold"),
            style.fill(color="lightgray")
        ],
        locations=loc.row_groups()
    )
)
html_data.append(gt.as_raw_html())
gt.show()
# Out:
# <div id="xdmkdijges" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #xdmkdijges table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #xdmkdijges thead, tbody, tfoot, tr, td, th { border-style: none; }
#  tr { background-color: transparent; }
# #xdmkdijges p { margin: 0; padding: 0; }
#  #xdmkdijges .gt_table { display: table; border-collapse: collapse; line-height: normal; margin-left: auto; margin-right: auto; color: #333333; font-size: 10; font-weight: normal; font-style: normal; background-color: snow; width: 100%; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; }
#  #xdmkdijges .gt_caption { padding-top: 4px; padding-bottom: 4px; }
#  #xdmkdijges .gt_title { color: #333333; font-size: 125%; font-weight: initial; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; border-bottom-color: snow; border-bottom-width: 0; }
#  #xdmkdijges .gt_subtitle { color: #333333; font-size: 85%; font-weight: initial; padding-top: 3px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; border-top-color: snow; border-top-width: 0; }
#  #xdmkdijges .gt_heading { background-color: snow; text-align: center; border-bottom-color: snow; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #xdmkdijges .gt_bottom_border { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #xdmkdijges .gt_col_headings { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; }
#  #xdmkdijges .gt_col_heading { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: bottom; padding-top: 6px; padding-bottom: 5px; padding-left: 5px; padding-right: 5px; overflow-x: hidden; }
#  #xdmkdijges .gt_column_spanner_outer { color: #FFFFFF; background-color: #004D80; font-size: 100%; font-weight: normal; text-transform: inherit; padding-top: 0; padding-bottom: 0; padding-left: 4px; padding-right: 4px; }
#  #xdmkdijges .gt_column_spanner_outer:first-child { padding-left: 0; }
#  #xdmkdijges .gt_column_spanner_outer:last-child { padding-right: 0; }
#  #xdmkdijges .gt_column_spanner { border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: bottom; padding-top: 6px; padding-bottom: 6px; overflow-x: hidden; display: inline-block; width: 100%; }
#  #xdmkdijges .gt_spanner_row { border-bottom-style: hidden; }
#  #xdmkdijges .gt_group_heading { padding-top: 0.5; padding-bottom: 0.5; padding-left: 5px; padding-right: 5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 1px; border-right-color: #D3D3D3; vertical-align: middle; text-align: left; }
#  #xdmkdijges .gt_empty_group_heading { padding: 0.5px; color: #333333; background-color: snow; font-size: 100%; font-weight: initial; border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: hidden; border-bottom-width: 2px; border-bottom-color: #929292; vertical-align: middle; }
#  #xdmkdijges .gt_from_md> :first-child { margin-top: 0; }
#  #xdmkdijges .gt_from_md> :last-child { margin-bottom: 0; }
#  #xdmkdijges .gt_row { padding-top: 9px; padding-bottom: 9px; padding-left: 5px; padding-right: 5px; margin: 10px; border-top-style: dashed; border-top-width: 1px; border-top-color: #929292; border-left-style: none; border-left-width: 1px; border-left-color: #929292; border-right-style: none; border-right-width: 1px; border-right-color: #929292; vertical-align: middle; overflow-x: hidden; }
#  #xdmkdijges .gt_stub { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: none; border-right-width: 2px; border-right-color: #FFFFFF; padding-left: 5px; padding-right: 5px; }
#  #xdmkdijges .gt_stub_row_group { color: #333333; background-color: snow; font-size: 100%; font-weight: initial; text-transform: inherit; border-right-style: solid; border-right-width: 2px; border-right-color: #D3D3D3; padding-left: 5px; padding-right: 5px; vertical-align: top; }
#  #xdmkdijges .gt_row_group_first td { border-top-width: 2px; }
#  #xdmkdijges .gt_row_group_first th { border-top-width: 2px; }
#  #xdmkdijges .gt_striped { background-color: #F4F4F4; }
#  #xdmkdijges .gt_table_body { border-top-style: solid; border-top-width: 2px; border-top-color: #929292; border-bottom-style: solid; border-bottom-width: 2px; border-bottom-color: #929292; }
#  #xdmkdijges .gt_sourcenotes { color: #333333; background-color: snow; border-bottom-style: none; border-bottom-width: 2px; border-bottom-color: #D3D3D3; border-left-style: none; border-left-width: 2px; border-left-color: #D3D3D3; border-right-style: none; border-right-width: 2px; border-right-color: #D3D3D3; }
#  #xdmkdijges .gt_sourcenote { font-size: 90%; padding-top: 4px; padding-bottom: 4px; padding-left: 5px; padding-right: 5px; text-align: left; }
#  #xdmkdijges .gt_left { text-align: left; }
#  #xdmkdijges .gt_center { text-align: center; }
#  #xdmkdijges .gt_right { text-align: right; font-variant-numeric: tabular-nums; }
#  #xdmkdijges .gt_font_normal { font-weight: normal; }
#  #xdmkdijges .gt_font_bold { font-weight: bold; }
#  #xdmkdijges .gt_font_italic { font-style: italic; }
#  #xdmkdijges .gt_super { font-size: 65%; }
#  #xdmkdijges .gt_footnote_marks { font-size: 75%; vertical-align: 0.4em; position: initial; }
#  #xdmkdijges .gt_asterisk { font-size: 100%; vertical-align: 0; }
#
# </style>
# <table class="gt_table" data-quarto-disable-processing="false" data-quarto-bootstrap="false">
# <thead>
#
#   <tr class="gt_heading">
#     <td colspan="7" class="gt_heading gt_title gt_font_normal"><div class="table-header">Table 15: Consented to extended followup</div></td>
#   </tr>
# <tr class="gt_col_headings">
#   <th class="gt_col_heading gt_columns_bottom_border gt_left" rowspan="1" colspan="1" scope="col" id="Consented">Consented</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="10">Hindu Mandal</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="20">Amana</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="30">Temeke</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="40">Mwananyamala</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="60">Mnazi Moja</th>
#   <th class="gt_col_heading gt_columns_bottom_border gt_center" rowspan="1" colspan="1" scope="col" id="total">Total</th>
# </tr>
# </thead>
# <tbody class="gt_table_body">
#   <tr class="

# %%
# gather raw html
raw_html = [f'<div class="page-break">{s}</div>' for s in html_data]
style_css = """
<style>
  .page-break {
    page-break-inside: avoid; /* Always add page break before this element */
  }
  .table-header {
    font-weight: bold;
    font-size: 18px;
    text-align: center;
    border-bottom: None;
  }
</style>
"""
raw_html = ''.join(raw_html)
raw_html = f'<!DOCTYPE html>\n<html lang="en">\n{style_css}\n<head>\n<meta charset="utf-8"/>\n</head>\n<body>\n' + document_title + raw_html + '\n</body>\n</html>\n'

# %%
# render html to PDF
pdfkit.from_string(raw_html, str(analysis_folder / pdf_filename),
                   options={
                       'footer-center': 'Page [page] of [topage]',
                       'footer-font-size': '8',
                       'footer-spacing': '5',
                       'encoding': "UTF-8",
                       'margin-top': '10mm',
                       'margin-right': '15mm',
                       'margin-bottom': '15mm',
                       'margin-left': '15mm',
                       'header-center': study_title,
                       'header-font-size': '6',
                       'header-spacing': '0',
                       'disable-javascript': None,
                       'no-outline': None,
                   },
                   verbose=True)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# True
