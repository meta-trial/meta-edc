# %%
# %%capture
import os
from pathlib import Path

from dj_notebook import activate

env_file = os.environ["META_ENV"]
# env_file = os.environ["META_ENV_REMOTE"]
analysis_folder = Path(os.environ["META_ANALYSIS_FOLDER"])
reports_folder = Path(os.environ["META_ANALYSIS_FOLDER"])
plus = activate(dotenv_file=env_file)

# %%
from edc_metadata.models import CrfMetadata
from clinicedc_constants import NEW
from django_pandas.io import read_frame
from clinicedc_utils import convert_visit_code_to_float

# %%
df = read_frame(CrfMetadata.objects.all())

# %%
df = convert_visit_code_to_float(df)

# %%
df[(df["model"] == "meta_subject.glucose") & (df["entry_status"] == NEW) & (
        df.visit_code == 1240.0)][["subject_identifier",
                                   "visit_code"]].sort_values("subject_identifier", ascending=True)

# %%
df
